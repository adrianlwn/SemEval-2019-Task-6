# %%
#from utils import *

import numpy as np
import torch
import matplotlib.pyplot as plt
import pandas as pd
import re
from os import mkdir
from os.path import join, isfile, isdir, exists
import bcolz
import pickle 
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset
import torch.optim as optim
#from pattern.en import spelling
from tqdm import tqdm
import ast

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload

# %%
GPU = True
device_idx = 0
if GPU:
    device = torch.device("cuda:" + str(device_idx) if torch.cuda.is_available() else "cpu")
else:
    device = torch.device("cpu")
print(device)
# Out:
# cuda:0

# %% [markdown]
# ## Word Embedings : GloVe
# This Class Loads the GloVe Embeding, processes it, and create a word embedding given the DataLoader.

# %%
class GloVe_embedding(object):
    def __init__(self,dim_vect = 25 ):
        ########## VARIABLES ##########
        self.dim_vect = dim_vect

        # Defining variables for GloVe: 
        self.words = []
        self.word2idx = {}
        self.glove_dict = {}
        
        ########## LOADING GLOVE DATA ##########
        
        # Defining path for GloVe Data : 
        self.path = join('..','data','glove') # Path of glove
        self.path_glove = join(self.path,'glove.twitter.27B.'+str(dim_vect))
        if not(isdir(self.path_glove)):
            mkdir(self.path_glove)
        self.path_vec_original = join(self.path,'glove.twitter.27B.'+str(dim_vect)+'d.txt') # Path of glove original vectors
        self.path_vec_save = join(self.path_glove,'glove.twitter.27B.'+str(dim_vect)+'d.vectors.dat')  # Path of glove saved vectors
        self.path_words = join(self.path_glove,'glove.twitter.27B.'+str(dim_vect)+'d.words.pkl')
        self.path_word2idx = join(self.path_glove,'glove.twitter.27B.'+str(dim_vect)+'d.word2idx.pkl')
                
        if not(isdir(self.path_vec_save) and isfile(self.path_words) and isfile(self.path_word2idx)) : 
            # If files are allready processed, just load them
            print('---- Processing the GloVe files : ',end='')
            self.process_GloVe()
            print('Done')
            
        # Load the wordvec files
        print('---- Loading the processed GloVe files : ',end='')
        self.load_GloVe()
        print('Done')
        
        ########## TORCH EMBEDDING ##########
        
        # Defining variables for our Embedding:
        self.size_vocab = len(self.words)
        
        # Creating the Pytorch Embedding Layer : 
        print('---- Creating the Pytorch Embedding Layer  : ',end='')
        self.emb_layer = nn.Embedding(self.size_vocab, self.dim_vect)
        self.create_emb_layer(non_trainable=True)
        print('Done')

               
    def process_GloVe(self):
        ''' Processes the GloVe Dataset - Saves files'''
        words = []
        word2idx = {}
        
        vectors = bcolz.carray(np.zeros(1) , rootdir=self.path_vec_save , mode='w' ) # defining vector saved
        
        # Adding Padding vector : 
        word2idx['<pad>'] = 0
        words.append('<pad>')
        #vect = np.random.normal(scale=0.6, size=(self.dim_vect , )) # random padding vect
        vect = np.zeros((self.dim_vect , )) # 0's padding vect. 
        vectors.append(vect)
        
        idx = 1
        with open(self.path_vec_original, 'rb') as f:
            for l in f:
                line = l.decode().split()
                word = line[0]
                words.append(word)
                word2idx[word] = idx
                idx += 1
                vect = np.array(line[1:]).astype(np.float)
                vectors.append(vect)
                

        vectors = bcolz.carray(vectors[:].reshape((-1, self.dim_vect)), rootdir=self.path_vec_save, mode='w')

        vectors.flush()
        pickle.dump(words, open(self.path_words, 'wb'))
        pickle.dump(word2idx, open(self.path_word2idx, 'wb'))
        
    def load_GloVe(self):
        ''' Loads previously processed dataset'''
        
        vectors = bcolz.open(self.path_vec_save)[:]
        
        self.words = pickle.load(open(self.path_words, 'rb'))
        self.word2idx = pickle.load(open(self.path_word2idx, 'rb'))
        
        self.glove_dict = {w: vectors[self.word2idx[w]] for w in self.words}
        self.emb_matrix = torch.Tensor(vectors)
    
    def create_emb_layer(self, non_trainable=True):
        self.emb_layer.load_state_dict({'weight': self.emb_matrix})
        if non_trainable:
            self.emb_layer.weight.requires_grad = False

# %%
myEmbedding = GloVe_embedding(dim_vect=200)
# Out:
# ---- Loading the processed GloVe files : Done
# ---- Creating the Pytorch Embedding Layer  : Done

# %% [markdown]
# ## Data Loader
# This Class Loads the Tweet Dataset, Cleans it. It also enables the loading for the training and testing.

# %%
class TestTweetDataset(Dataset):
    ''' 
    Pytorch Dataset for the Test set. 
    initialisation : - data : training pandas dataframe
                     - subtask : subtask we are working on {'subtask_a', 'subtask_b', 'subtask_c', }
                     - balanced : if we balance the dataset by oversampling it in the smallest classes
    '''
    def __init__(self,data, subtask):
        self.id = data.index.tolist()
        self.token = data.token.tolist()
        self.token_id = data.token_id.tolist()
        
    def __getitem__(self, index):
        return torch.LongTensor(self.token_id[index]), torch.FloatTensor([self.id[index]])

    def __len__(self):
        return len(self.token) 

        
    
class TweetDataset(Dataset):
    ''' 
    Pytorch Dataset for the Training set. 
    initialisation : - data : training pandas dataframe
                     - subtask : subtask we are working on {'subtask_a', 'subtask_b', 'subtask_c', }
                     - balanced : if we balance the dataset by oversampling it in the smallest classes
    '''
    def __init__(self,data,subtask):        
        # Save in lists the ids, labels, label_id, token, and token_id . 
        self.id = data.index.tolist()
        self.label_id = data[subtask].tolist()
        self.token = data.token.tolist()
        self.token_id = data.token_id.tolist()
        
    def __getitem__(self, index):
        return torch.LongTensor(self.token_id[index]), torch.FloatTensor([self.label_id[index]])

    def __len__(self):
        return len(self.token)

# %%
class DataHandling(object):
    def __init__(self, embedding, pValid):
        print('-- Data Handling : ')
        
        self.embedding = embedding
        
        self.defineClasses()

        # All the Text Data path
        self.definePath()
        
        self.data = {}
        
        processed_ = True
        for f in self.path:
            processed_ = processed_ and isfile(self.path_clean[f])
        
        if  not(processed_) : 
            ### PROCESSING OF THE ORIGINAL DATASET
            # Load, Clean and Tokenize the Datasets
            print('---- Load, Clean and Tokensize Dataset : ',end='')
            self.inital_dataload()
            print('Done')
            
            # Compute List of All words in the datasets
            print('---- Finalize tokenized words and translation to id : ',end='')
            self.compute_wordlist()
            self.token2id()
            print('Done')

            # Add Embedding and correct clean the words not in embedding : 
            print('---- Adapt Dataset for Embedding : ',end='')
            self.adaptDataset()
            print('Done')

            # Save the Cleaned Datasets
            print('---- Saving all tokenized words : ',end='')
            self.save_cleanDataset()
            print('Done')
        else : 
            # Save the Cleaned Datasets
            print('---- Load the Clean Adapted Dataset : ',end='')
            self.load_cleanDataset()
            
            # Compute List of All words in the datasets
            self.compute_wordlist()
            print('Done')
        
        # Create Validation Set (split the test dataset) for every subtask
        self.splitValidation(p=pValid)
        self.prepareLabels()
        
        
    def defineClasses(self):
        ''' Function that defines the classes labels and id per subtask '''
        self.classes_dict = {}
        self.classes_dict['subtask_a'] = {'NOT' : 0 ,'OFF' : 1}
        self.classes_dict['subtask_b'] = {'UNT' : 0 ,'TIN' : 1}
        self.classes_dict['subtask_c'] = {'IND' : 0 ,'OTH' : 1, 'GRP' : 2}
        
    def definePath(self):
        ''' Function that defines all the paths of the datasets. '''
        self.path = {}
        self.path_clean = {}
        
        self.path['train'] = join('..','data','start-kit','training-v1','offenseval-training-v1.tsv')
        self.path_clean['train'] = join('..','data','start-kit','training-v1','clean-offenseval-training-v1.tsv')
        
        self.path['subtask_a'] = join('..','data','Test A Release','testset-taska.tsv')
        self.path_clean['subtask_a'] = join('..','data','Test A Release','clean-testset-taska.tsv')
        
        self.path['subtask_b'] = join('..','data','Test B Release','testset-taskb.tsv')
        self.path_clean['subtask_b'] = join('..','data','Test B Release','clean-testset-taskb.tsv')
        
        self.path['subtask_c'] = join('..','data','Test C Release','test_set_taskc.tsv')
        self.path_clean['subtask_c'] = join('..','data','Test C Release','clean-test_set_taskc.tsv')
        
    def getDataset(self, dataT='train',subtask='subtask_a',balanced = True):
        ''' Returns the pytorch Dataset
            - file : {'train','test','validation'}
            - subtask : {'subtask_a','subtask_b','subtask_c'} '''
        
            
        if dataT == 'train':
            if balanced : 
                data_train = self.balanceData(self.data[dataT][subtask],subtask)
            else : 
                data_train = self.data[dataT][subtask]
            dataset = TweetDataset(data_train, subtask)
        elif dataT == 'validation':
            dataset = TweetDataset(self.data[dataT][subtask], subtask)
        elif dataT == 'test':
            dataset = TestTweetDataset(self.data[subtask], subtask)
            
        return dataset
    
    def token2id(self):
        ''' Function that translates the list of tokens into a list of token id of the embedding.
            Adds a new 'token_id' column to the dataframe '''
        for f in self.path : 
            def token2id_x(x):
                
                return [self.embedding.word2idx[k] for k in x if k in self.embedding.words]
            self.data[f]['token_id'] = self.data[f]['token'].apply(lambda x : token2id_x(x))

    def save_cleanDataset(self):
        ''' Saves at the defined path the cleaned dataset '''
        for f in self.path : 
            self.data[f].to_csv(self.path_clean[f])
        
    def load_cleanDataset(self):
        ''' Loads at the defined path the cleaned dataset '''
        for f in self.path : 
            self.data[f] = pd.read_csv(self.path_clean[f],index_col='id')
            self.data[f]['token'] = self.data[f]['token'].apply(lambda x : ast.literal_eval(x))
            self.data[f]['token_id'] = self.data[f]['token_id'].apply(lambda x : ast.literal_eval(x))
           
               
    def adaptDataset(self):
        ''' Function that finds all the words which are not in the embedding and tries to 
            correct them with the pattern.en package by taking the most probable replacement.
            If the suggested word in very unlikely, the word is removed from the tweets. 
        '''
        # Find all words wich are not in the Embedding :
        missing_words = []
        for i, word in enumerate(self.all_words) :
            if self.embedding.word2idx.get(word) == None : 
                missing_words.append(word)
        
        # Correct if possible the missing_words : 
        ### We use theshold over which we correct the word. Under which we discard the word
        t = 0.5 # threshold
        rejected_words = []
        corrected_words = {}
        for word in tqdm(missing_words) : 
            suggestion, prob = spelling.suggest(word)[0]
            if prob < t : 
                rejected_words.append(word)
            else : 
                corrected_words[word] = suggestion
        
        # Modify the Original Datasets with those corrected_words : 
        for f in self.path : 
            self.data[f]['token'] = self.data[f]['token'].apply(lambda x : [corrected_words.get(k,k) for k in x])
            self.data[f]['token'] = self.data[f]['token'].apply(lambda x : [k for k in x if k not in rejected_words ])
        nb_rejected = len(rejected_words)
        nb_corrected = len(corrected_words)
        nb_vocab = len(self.embedding.glove_dict)
        p_rejected = 100* nb_rejected / nb_vocab
        p_corrected = 100* nb_corrected / nb_vocab
        print('---- Words removed   : {0:} / {1:.2f} - {2:} %'.format(nb_rejected,nb_vocab,p_rejected))
        print('---- Words corrected : {0:} / {1:.2f} - {2:} %'.format(nb_corrected,nb_vocab,p_corrected))
        
    def inital_dataload(self):
        for f in self.path : 
            self.data[f] = pd.read_table(self.path[f],index_col='id')
            self.data[f]['token'] = self.data[f]['tweet'].apply(lambda x : self.clean_tweet(x))
            
    def compute_wordlist(self):
        self.all_words_freq = {}
        self.all_words = []
        
        for f in self.data : 
            for i in range(len(self.data[f])):
                for e in self.data[f].iloc[i].token:
                    self.all_words_freq[e] = 1 + self.all_words_freq.get(e,0)
        self.all_words = list(self.all_words_freq.keys())
        
    def splitValidation(self,p):
        ''' Creates the validation set by  taking p % of the train dataset '''
        data = self.data['train'].copy()
        self.data['train'] = {}
        self.data['validation'] = {}

        for subtask in self.classes_dict: # per subtask
            self.data['train'][subtask] = pd.DataFrame()
            self.data['validation'][subtask]= pd.DataFrame()
            for label in self.classes_dict[subtask]: #per label in this subtask 
                data_label =  data[data[subtask]==label]
                self.data['train'][subtask] = self.data['train'][subtask].append(data.loc[data_label.index])
                nb_valid = int(len(data_label)*p)
                # Select randmoly (without repetition) the indexes of the selected vaidation tweets
                index_valid = np.random.choice(data_label.index,(nb_valid,),replace=False)
                # Add the the selected validation tweets to the new dataframe
                self.data['validation'][subtask] = self.data['validation'][subtask].append(self.data['train'][subtask].loc[index_valid,:])
                # Drop the selected validation tweets from the training set
                self.data['train'][subtask] = self.data['train'][subtask].drop(index = index_valid)
                
    def prepareLabels(self) : 
        ''' Transform the labels into classes id '''
        for subtask in self.classes_dict: # per subtask
            self.data['validation'][subtask][subtask] =self.data['validation'][subtask][subtask].apply(lambda x : self.classes_dict[subtask][x])  
            self.data['train'][subtask][subtask] = self.data['train'][subtask][subtask].apply(lambda x : self.classes_dict[subtask][x])  

    def balanceData(self,data,subtask):
        ''' Augments the Data given in input in order to balance the dataset'''
        class_size = {}
        for label in self.classes_dict[subtask]:
            class_size[label] = len(data[data[subtask]==self.classes_dict[subtask][label]])
        largest_class = max(class_size, key=class_size.get)
        print('---- Augmenting the Data : ')
        print('Before Augmentation : ',class_size)

        for label in self.classes_dict[subtask]:  
            if label != largest_class:
                id_list = data[data[subtask]==self.classes_dict[subtask][label]].index
                nb_augmentation = class_size[largest_class] - class_size[label]
                id_augmentation = np.random.choice(id_list, (nb_augmentation,))
                data = data.append(data.loc[id_augmentation,:])
        # Check if it went well
        for label in self.classes_dict[subtask]:
            class_size[label] = len(data[data[subtask]==self.classes_dict[subtask][label]])
        
        print('After Augmentation : ',class_size)
        return data
    
    def clean_tweet(self,text):
        ''' Function that is applied to every to tweet in the dataset '''
        
        # =========== TEXT ===========
        # Replace @USER by <user>
        text = re.compile(r'@USER').sub(r'<user>',text)

        # Replace URL by <url>
        text = re.compile(r'URL').sub(r'<url>',text)

        # Remove numbers :
        text = re.compile(r'[0-9]+').sub(r' ',text)

        # Remove some special characters
        text = re.compile(r'([\xa0_\{\}\[\]¬•$,:;/@#|\^*%().~`”"“-])').sub(r' ',text) 

        # Space the special characters with white spaces
        text = re.compile(r'([$&+,:;=?@#|\'.^*()%!"’“-])').sub(r' \1 ',text)
        
        # Replace some special characters : 
        replace_dict = {r'&' : 'and' , 
                        r'\+' : 'plus'}
        for cha in replace_dict:
            text = re.compile(str(cha)).sub(str(replace_dict[cha]),text)
            
        # Handle Emoji : translate some and delete the others
        text = self.handle_emoji(text)
        
        # Word delengthening : 
        text = re.compile(r'(.)\1{3,}').sub(r'\1\1',text)

        # Cut the words with caps in them : 
        text = re.compile(r'([a-z]+|[A-Z]+|[A-Z][a-z]+)([A-Z][a-z]+)').sub(r'\1 \2',text)
        text = re.compile(r'([a-z]+|[A-Z]+|[A-Z][a-z]+)([A-Z][a-z]+)').sub(r'\1 \2',text)        
        # =========== TOKENS ===========
        # TOKENIZE 
        text = text.split(' ')

        # Remove white spaces tokens
        text = [text[i] for i in range(len(text)) if text[i] != ' ']

        # Remove empty tokens
        text = [text[i] for i in range(len(text)) if text[i] != '']

        # Remove repetition in tokens (!!! => !)
        text = [text[i] for i in range(len(text)) if text[i] != text[i-1]]

        #  Handle the ALL CAPS Tweets 
        ### if ratio of caps in the word > 75% add allcaps tag <allcaps>
        caps_r = np.mean([text[i].isupper() for i in range(len(text))])
        if caps_r > 0.6 : 
            text.append('<allcaps>')

        # Lower Case : 
        text = [text[i].lower() for i in range(len(text))]

        return text

    def handle_emoji(self,text):
        # Dictionnary of "important" emojis : 
        emoji_dict =  {'♥️': ' love ',
                       '❤️' : ' love ',
                       '❤' : ' love ',
                       '😘' : ' kisses ',
                      '😭' : ' cry ',
                      '💪' : ' strong ',
                      '🌍' : ' earth ',
                      '💰' : ' money ',
                      '👍' : ' ok ',
                       '👌' : ' ok ',
                      '😡' : ' angry ',
                      '🍆' : ' dick ',
                      '🤣' : ' haha ',
                      '😂' : ' haha ',
                      '🖕' : ' fuck you '}

        for cha in emoji_dict:
            text = re.compile(str(cha)).sub(str(emoji_dict[cha]),text)
        # Remove ALL emojis
        text = emoji.get_emoji_regexp().sub(r' ',text) 
        text = re.compile("([\U0001f3fb-\U0001f3ff])").sub(r'',text) 
        text = re.compile("([\U00010000-\U0010ffff])").sub(r'',text) 
        text = re.compile("(\u00a9|\u00ae|[\u2000-\u3300]|\ud83c[\ud000-\udfff]|\ud83d[\ud000-\udfff]|\ud83e[\ud000-\udfff])").sub(r'',text)

        # Add Space between  the Emoji Expressions : 
        text = re.compile("([\U00010000-\U0010ffff])").sub(r' \1 ',text) 
        return text

# %%
mydata = DataHandling(myEmbedding, pValid=0.15)
# Out:
# -- Data Handling :
# ---- Load the Clean Adapted Dataset : Done

# %%
mydata.data['train']['subtask_a'].head(10)
# Out:
#                                                    tweet  subtask_a subtask_b  \
# id
# 16820  Amazon is investigating Chinese employees who ...          0       NaN
# 43605  @USER @USER Obama wanted liberals &amp; illega...          0       NaN
# 45157                         @USER Buy more icecream!!!          0       NaN
# 42992  @USER What’s the difference between #Kavanaugh...          0       NaN
# 54920  @USER @USER @USER It should scare every Americ...          0       NaN
# 56392  @USER @USER @USER @USER @USER @USER @USER @USE...          0       NaN
# 86735               @USER you are also the king of taste          0       NaN
# 71446  5/5: @USER The time is right for this House to...          0       NaN
# 23958  @USER Besides Jax’s mom and maybe Ope he is ha...          0       NaN
# 67757                       @USER @USER You are correct.          0       NaN
#
#       subtask_c                                              token  \
# id
# 16820       NaN  [amazon, is, investigating, chinese, employees...
# 43605       NaN  [<user>, obama, wanted, liberals, and, amp, il...
# 45157       NaN                   [<user>, buy, more, icecream, !]
# 42992       NaN  [<user>, what, s, the, difference, between, an...
# 54920       NaN  [<user>, it, should, scare, every, american, !...
# 56392       NaN  [<user>, i, like, my, soda, like, i, like, my,...
# 86735       NaN     [<user>, you, are, also, the, king, of, taste]
# 71446       NaN  [<user>, the, time, is, right, for, this, hous...
# 23958       NaN  [<user>, besides, jax, s, mom, and, maybe, ope...
# 67757       NaN                        [<user>, you, are, correct]
#
#                                                 token_id
# id
# 16820  [2547, 33, 39459, 3492, 16270, 128, 71, 5442, ...
# 43605  [1, 1382, 953, 30168, 27, 12801, 114750, 17, 9...
# 45157                           [1, 873, 146, 18658, 10]
# 42992  [1, 87, 138, 14, 2954, 1472, 27, 1, 97, 40, 37...
# 54920  [1, 34, 277, 9603, 382, 2034, 10, 148, 33, 701...
# 56392  [1, 11, 64, 30, 9477, 64, 11, 64, 30, 290103, ...
# 86735               [1, 16, 71, 895, 14, 1697, 40, 3212]
# 71446  [1, 14, 136, 33, 209, 38, 54, 544, 17, 7094, 1...
# 23958  [1, 8101, 43627, 138, 570, 27, 718, 50199, 108...
# 67757                                  [1, 16, 71, 5550]

# %%
# Example of Tweet Processing
print(mydata.data['train']['subtask_a'].iloc[331]['tweet'])
print(mydata.data['train']['subtask_a'].iloc[331]['token'])
print(mydata.data['train']['subtask_a'].iloc[331]['token_id'])
# Out:
# @USER @USER @USER @USER @USER @USER @USER @USER @USER @USER @USER @USER @USER @USER @USER @USER @USER @USER You are suggesting that it is not the     law and policy (sanctions regime) that informs rates of benefit sanctions. The graph would suggest that is true as by 2017 the sanctions rate was lower than it was under the previous sanctions regime. Good observations about pressure"++"
# ['<user>', 'you', 'are', 'suggesting', 'that', 'it', 'is', 'not', 'the', 'law', 'and', 'policy', 'sanctions', 'regime', 'that', 'informs', 'rates', 'of', 'benefit', 'sanctions', 'the', 'graph', 'would', 'suggest', 'that', 'is', 'true', 'as', 'by', 'the', 'sanctions', 'rate', 'was', 'lower', 'than', 'it', 'was', 'under', 'the', 'previous', 'sanctions', 'regime', 'good', 'observations', 'about', 'pressure', 'plus']
# [1, 16, 71, 49077, 46, 34, 33, 79, 14, 3188, 27, 10185, 41954, 22981, 46, 163098, 12821, 40, 11412, 41954, 14, 34884, 197, 11276, 46, 33, 548, 125, 153, 14, 41954, 3761, 94, 7671, 286, 34, 94, 1478, 14, 11887, 41954, 22981, 118, 90738, 122, 5850, 839]

# %% [markdown]
# ## Classifier
# Set of Classes used as classifier for the tweets.

# %%
# Classification NN : 
class FFNN(nn.Module):
    
    def __init__(self, embedding, hidden_dim , num_classes ,embedding_dim):
        print('------ Creating FFNN : ',end='')
        
        super(FFNN, self).__init__()
        
        # Embedding
        self.embedding = embedding
        
        # Fully Connected Layers
        self.fc1 = nn.Linear(embedding_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, num_classes) 
        torch.nn.init.xavier_uniform_(self.fc1.weight)
        torch.nn.init.xavier_uniform_(self.fc2.weight)

        # Activation Layers
        self.relu1 = nn.ReLU()

        self.output = nn.LogSoftmax(dim=1)
        print('Done')
    
    def forward(self, x):
        
        embedded = self.embedding(x)
        # we average the embeddings of words in a sentence
        
        non_zero_nb = (x!=0).sum(1,keepdim=True)
        #print(x.shape, non_zero_nb,embedded.sum(1).shape)
        averaged = embedded.sum(1) / non_zero_nb.float()
        #averaged = embedded.mean(1)
        # (batch size, max sent length, embedding dim) to (batch size, embedding dim)

        out = self.fc1(averaged)
        out = self.relu1(out)
        out = self.fc2(out)
        out = self.output(out)
        return out
    
    def loss_fn(self):
        ''' Returns the loss function best associated with the model'''
        return nn.NLLLoss()

# %%
# CNN : 
class CNN(nn.Module):
    
    def __init__(self, embedding, embedding_dim, out_channels, window_size, output_dim, dropout):
        
        super(CNN, self).__init__()
        
        self.embedding = embedding
        
        #in_channels -- 1 text channel
        #out_channels -- the number of output channels
        #kernel_size is (window size x embedding dim)
        
        self.conv = nn.Conv2d(in_channels=1, out_channels=out_channels, kernel_size=(window_size,embedding_dim))
        
        #the dropout layer
        self.dropout = nn.Dropout(dropout)
    
        #the output layer
        self.fc = nn.Linear(out_channels, output_dim)
        
        self.out =  nn.LogSoftmax(dim=1)
        
    def forward(self, x):
                
        #(batch size, max sent length)
        
        embedded = self.embedding(x)
        #print('embedded',embedded.shape)
                
        #(batch size, max sent length, embedding dim)
        
        #images have 3 RGB channels 
        #for the text we add 1 channel
        embedded = embedded.unsqueeze(1)
        #print('embedded_unsqueeze',embedded.shape)
        
        #(batch size, 1, max sent length, embedding dim)
        
        feature_maps = self.conv(embedded)
        #print('feature_maps',feature_maps.shape)

        #??? what is the shape of the convolution output
        
        #(batch size, n filters, max input length - window size +1, 1)
        
        feature_maps = feature_maps.squeeze(3)
        #print('feature_maps_unsqueeze',feature_maps.shape)

        #??? why do we reduce 1 dimention here
        
        # we do need the 1 channel anymore
                
        feature_maps = F.relu(feature_maps)
        #print('feature_maps_relu',feature_maps.shape)

  
        #the max pooling layer
        pooled = F.max_pool1d(feature_maps, feature_maps.shape[2])
        #print('pooled',pooled.shape)

        pooled = pooled.squeeze(2)
        #print('pooled_squeeze',pooled.shape)

        #??? what is the shape of the pooling output
        #(batch size, n_filters)
        
        dropped = self.dropout(pooled)
        #print('dropped',dropped.shape)

        preds = self.fc(dropped)
        #print('preds', preds.shape)
        out = self.out(preds)
        #print('out',out.shape)
        
        return out
    
    def loss_fn(self):
        return nn.NLLLoss()

# %%
class CNN_paper(nn.Module):
    '''based on https://arxiv.org/pdf/1408.5882'''
    def __init__(self, embedding, embedding_dim, out_channels, window_size, output_dim, dropout):
        
        super(CNN_paper, self).__init__()
        
        self.embedding = embedding

        
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=out_channels, kernel_size=(window_size[0],embedding_dim))
        self.conv2 = nn.Conv2d(in_channels=1, out_channels=out_channels, kernel_size=(window_size[1],embedding_dim))
        self.conv3 = nn.Conv2d(in_channels=1, out_channels=out_channels, kernel_size=(window_size[2],embedding_dim))
        #the dropout layer
        self.dropout = nn.Dropout(dropout)
    
        #the output layer
        self.fc = nn.Linear(out_channels*3, output_dim)
        
        self.out =  nn.LogSoftmax(dim=1)
    
    def conv_block(self,embedded,conv_layer):
        feature_maps = conv_layer(embedded)
        features_maps = feature_maps.squeeze(3)
        feature_maps = F.relu(feature_maps)
        return F.max_pool1d(feature_maps, feature_maps.shape[2]).squeeze(2)
    
    def forward(self, x):
                
        #(batch size, max sent length)
        
        embedded = self.embedding(x)
                        
        #images have 3 RGB channels 
        #for the text we add 1 channel
        embedded = embedded.unsqueeze(1)
         

        feature_maps1 = self.conv1(embedded)
        feature_maps2 = self.conv2(embedded)
        feature_maps3 = self.conv3(embedded)
        
        feature_maps1 = feature_maps1.squeeze(3)
        feature_maps2 = feature_maps2.squeeze(3)
        feature_maps3 = feature_maps3.squeeze(3)


                
        feature_maps1 = F.relu(feature_maps1)
        feature_maps2 = F.relu(feature_maps2)
        feature_maps3 = F.relu(feature_maps3)

  
        #the max pooling layer
        pooled1 = F.max_pool1d(feature_maps1, feature_maps1.shape[2])
        pooled2 = F.max_pool1d(feature_maps2, feature_maps2.shape[2])
        pooled3 = F.max_pool1d(feature_maps3, feature_maps3.shape[2])

        pooled1 = pooled1.squeeze(2)
        pooled2 = pooled2.squeeze(2)
        pooled3 = pooled3.squeeze(2)
        all_pooled =torch.cat((pooled1, pooled2, pooled3), 1)
        
        dropped = self.dropout(all_pooled)

        preds = self.fc(dropped)
        out = self.out(preds)
        
        return out
    
    def loss_fn(self):
        return nn.NLLLoss()

# %%
# RNN, GRU and LSTM
class RNN_base(nn.Module):
    def __init__(self, embedding, embedding_dim=25, hidden_size=25, output_size=2, num_layers=1, output_layer=None):
        super(RNN_base, self).__init__()
        
        self.hidden_size = hidden_size
        self.embedding = embedding
        
        if output_layer==None:
            self.i2o = nn.Linear(hidden_size, output_size)
        else:
            self.i2o = output_layer
        self.final_activation = nn.LogSoftmax(dim=1)
        self.final_activation = nn.LogSoftmax(dim=1)
        
        
    def forward(self, inputs):
        inputs_embedded = self.embedding(inputs).float()
 
        sentence_lengths = (inputs_embedded.sum(dim=2,keepdim=False)!=0).sum(dim=1)
        
        output, hidden = self.rnn(inputs_embedded)
        
        output_final = torch.empty(inputs.shape[0],self.hidden_size).float()
        output_final = output[torch.arange(inputs.shape[0]),sentence_lengths-1,:]

        output = self.i2o(output_final)
        output = self.final_activation(output)
        
        return output

    def loss_fn(self):
        ''' Returns the loss function best associated with the model'''
        return nn.NLLLoss()
    
class RNN(RNN_base):
    def __init__(self, embedding, embedding_dim=25, hidden_size=25, output_size=2, num_layers=1, output_layer=None):
        RNN_base.__init__(self, 
                          embedding=embedding, 
                          embedding_dim=embedding_dim, 
                          hidden_size=hidden_size, 
                          output_size=output_size, 
                          num_layers=num_layers, 
                          output_layer=output_layer)
        self.rnn = nn.RNN(
            input_size = embedding_dim, 
            hidden_size = hidden_size,
            num_layers = num_layers,
            nonlinearity = "relu",
            batch_first = True
        )

class LSTM(RNN_base):
    def __init__(self, embedding, embedding_dim=25, hidden_size=25, output_size=2, num_layers=1, output_layer=None):
        RNN_base.__init__(self, 
                          embedding=embedding, 
                          embedding_dim=embedding_dim, 
                          hidden_size=hidden_size, 
                          output_size=output_size, 
                          num_layers=num_layers, 
                          output_layer=output_layer)
        self.rnn = nn.LSTM(
            input_size = embedding_dim, 
            hidden_size = hidden_size,
            num_layers = num_layers,
            batch_first = True
        )  
        
class GRU(RNN_base):
    def __init__(self, embedding, embedding_dim=25, hidden_size=25, output_size=2, num_layers=1, output_layer=None):
        RNN_base.__init__(self, 
                          embedding=embedding, 
                          embedding_dim=embedding_dim, 
                          hidden_size=hidden_size, 
                          output_size=output_size, 
                          num_layers=num_layers, 
                          output_layer=output_layer)
        self.rnn = nn.GRU(
            input_size = embedding_dim, 
            hidden_size = hidden_size,
            num_layers = num_layers,
            batch_first = True
        ) 
        
def output_layer(input_size,output_size,middle_layers=[]):
    "Input and output size - scalars. Middle layers - list (ignore if just one layer wanted)"
    
    #For current implementation, the input_size should be equal to the size of the hidden layer for the RNNs.
    activation = nn.ReLU()

    component_layers=[]
    if middle_layers!=[]:

        component_layers.append(
            nn.Linear(
                in_features  = input_size,
                out_features  = middle_layers[0]))
        component_layers.append(activation)


        if len(middle_layers)>1:
            for layer in range(1,len(middle_layers)):
                component_layers.append(
                    nn.Linear(in_features  = middle_layers[layer-1],
                              out_features  = middle_layers[layer]))
                component_layers.append(activation)

        component_layers.append(
            nn.Linear(in_features  = middle_layers[-1],
                      out_features  = output_size))

    else:
        component_layers.append(
            nn.Linear(in_features  = input_size,
                      out_features  = output_size))

    i2o = nn.Sequential(*component_layers)
    
    return i2o

# %% [markdown]
# Pad Data Method : Used with the pytorch DataLoader in order to pad the length of the tweets by batch.

# %%
class padding_tweet:
    '''
    Pad Data Method : Used with the pytorch DataLoader in order to pad the length of the tweets by batch. 
    args: 
        batch - List of elements ( x , label )
    return 
        batch - Padded ( list(x) , list(label))
    
    '''
    def __init__(self, max_len):
        self.max_len = max_len
    def __call__(self,batch):
        
        batch = list(zip(*batch))
       
        batch[0] = torch.stack([self.pad_tensor(vec=t, pad=self.max_len, dim=0) for t in batch[0]],dim=0)
        batch[1] = torch.stack(batch[1])
        return batch[0] , batch[1]

    def pad_tensor(self,vec, pad, dim):
        """
        args:
            vec - tensor to pad
            pad - the size to pad to
            dim - dimension to pad

        return:
            a new tensor padded to 'pad' in dimension 'dim'
        """
        pad_size = list(vec.shape)
        pad_size[dim] = pad - vec.size(dim)
        return torch.cat([vec, torch.zeros(*pad_size,dtype=torch.long)], dim=dim)

# %% [markdown]
# ## Main Class : Trainer
# Main Class for the loading, training, testing etc ...

# %%
class OffensiveClassifier(object):
    ''' Main Class for the loading, training, testing etc ...'''
    def __init__(self,subtask='subtask_a', dim_vect=25,pValid = 0.15):
        
        self.dim_vect = dim_vect
        
        self.subtask = subtask
        

        # Loading the GloVe Embedding and Torch Formating of this Embedding
        self.GloVe = GloVe_embedding(dim_vect= dim_vect )
        self.embedding = self.GloVe.emb_layer
        
        # Loading the Data Handler : 
        self.dataHandler = DataHandling(self.GloVe,pValid=pValid)
        
        # Retrieving Training DataSet (pytorch)
        self.train_set = self.dataHandler.getDataset('train',subtask,balanced=True)
        
        # Retrieving the Validation Set (pytorch)
        self.valid_set = self.dataHandler.getDataset('validation',subtask)

        # Retrieving Test DataSet (pytorch)
        self.test_set = self.dataHandler.getDataset('test',subtask)
        
        # Usefull info on classes : 
        self.class2id  = self.dataHandler.classes_dict[self.subtask]
        self.id2class = dict(zip(self.class2id.values(),self.class2id.keys()))
        self.nb_class = len(self.class2id)
        self.max_len  = max([ max([len(t) for t in self.train_set.token]),
                              max([len(t) for t in self.valid_set.token]),
                              max([len(t) for t in self.test_set.token])])
            
        
    
    def train( self, nb_epochs, optimizer , model , batch_size = 1000 ,  ):
        
        self.train_generator = DataLoader(self.train_set, batch_size=batch_size,collate_fn=padding_tweet(self.max_len), shuffle=True)

        self.model = model.to(device)
        loss_fn = self.model.loss_fn()

        for epoch in range(nb_epochs):
            i_batch = 0
            accuracy_average = 0
            self.model.train() 
            
            for tokens, target  in self.train_generator :
                i_batch += 1
                target = target.long().view((-1,)).to(device)
                tokens = tokens.long().to(device)
                #to ensure the dropout (exlained later) is "turned on" while training
                #good practice to include even if do not use here
                self.model.train()

                #we zero the gradients as they are not removed automatically
                optimizer.zero_grad()

                output = self.model(tokens)
                #print(output.shape)

                predictions = torch.argmax(output,dim=1).float()
                loss = loss_fn(output, target)
                acc, correct = self.accuracy(predictions, target)
                accuracy_average += acc
                #calculate the gradient of each parameter
                loss.backward()
                
                #update the parameters using the gradients and optimizer algorithm 
                optimizer.step()

                epoch_loss = loss.item()

                if i_batch % (nb_epochs -1 )  ==0:
                    pass
            print(f'| Epoch: {epoch:02} | Train Loss: {epoch_loss:.3f} | Train Acc: {accuracy_average*100/i_batch:.2f}%')
            f1 = self.validation(batch_size = 50)
            print('=============================================================================')
            print()
            #return f1
            
    def validation(self, batch_size = 1000):
        all_correct = 0
        self.validation_generator = DataLoader(self.valid_set, batch_size=batch_size, collate_fn=padding_tweet(self.max_len), shuffle=True)
        loss_fn = self.model.loss_fn()
        nb_valid = len(classifier.valid_set)
        self.model.eval()  # set model to evaluation mode
        all_prediction = []
        all_target = []
        
        with torch.no_grad(): 
            for tokens, target  in self.validation_generator :
                target = target.long().view((-1,)).to(device)
                tokens = tokens.long().to(device)
                
                output = self.model(tokens)
                predictions = torch.argmax(output,dim=1)
                
                loss = loss_fn(output, target)
                
                all_prediction.extend(predictions.view(-1,).tolist())
                all_target.extend(target.view(-1,).tolist())
                
        accuracy, CM, stats_df = self.results(all_prediction,all_target)
        print(f'| Stats on the Validation : ')
        print(stats_df)
        
        print(f'| Validation Accuracy : {100*accuracy:.2f} % - Macro F1 Score : {stats_df.loc["f1-measure"].mean():.4f} ')
        print(f'| CM on the Validation : ')
        print(CM)
        print()
        #return stats_df.loc["f1-measure"].mean()
        
    def test(self,folder):
        ''' 
            Test Function : Tests the Network on the Test Data of the Subtask and Saves in a file
        '''
        test_result = pd.DataFrame()
        self.test_generator = DataLoader(self.test_set,collate_fn= padding_tweet(self.max_len) )
        nb_valid = len(classifier.valid_set)
        self.model.eval()  # set model to evaluation mode
        all_prediction = []
        all_id = []
        with torch.no_grad(): 
            for tokens, id_tweet  in self.test_generator :
                id_tweet = id_tweet.long().view((-1,))
                tokens = tokens.long().to(device)
                
                output = self.model(tokens)
                predictions = torch.argmax(output,dim=1)
                
                all_prediction.extend(predictions.view(-1,).tolist())
                all_id.extend(id_tweet.view(-1,).tolist())
        results_df = pd.DataFrame(all_prediction, index=all_id)
              
        # Change id_labels to labels
        results_df[0] = results_df[0].apply(lambda x : self.id2class[x])
              
        # Saving the Results in the right format in the folder ../data/results/*folder*
        save_path = join('..','data','results')
        if not(exists(save_path)) : mkdir(save_path)
        save_path = join(save_path,folder)
        if not(exists(save_path)) : mkdir(save_path)
        
        path_file = join(save_path, self.subtask + '.csv')
        i = 0
        while exists(path_file):
              i += 1
              path_file = join(save_path, self.subtask + '_'+ str(i) +'.csv')
        results_df.to_csv(path_file, header=False)
        print('| Successfully save to : ', path_file)
        

    def accuracy(self, output, target):
        target = np.array(target.tolist()).astype(int)
        output = np.array(torch.round(output).tolist()).astype(int)
        correct = (output == target)
        accuracy = correct.sum()/len(correct)
        return accuracy, correct
        
    def results(self, output, target ):
        target = np.array(target).astype(int)
        output = np.round(output).astype(int)
        correct = (output == target)
        accuracy = correct.sum()/len(correct)
        
        CM = np.zeros((self.nb_class,self.nb_class))
        for i in range(len(output)): 
            CM[target[i], output[i]] += 1
        
        # compute the interesting stats on the classification : 
        stats_df = self.stats(CM)
        stats_df.columns = map(lambda x : self.id2class[x] ,stats_df.columns)
        return (accuracy, CM, stats_df)

    def stats(self,CM):   
        n_class = self.nb_class
    
        stats = {}
        stats['precision'] = {} 
        stats['recall'] = {} 
        stats['accuracy'] = {} 
        stats['f1-measure'] = {} 

        for t in range(self.nb_class):
            tp = CM[t,t]
            tn = np.sum([CM[i,i] for i in range(self.nb_class) if i != t])

            fp = np.sum([CM[i,t] for i in range(self.nb_class) if i != t])
            fn = np.sum([CM[t,i] for i in range(self.nb_class) if i != t])

            # compute accuracy per class :
            accuracy = (tp + tn) / (tp + tn + fp + fn)

            # compute recall per class
            recall = tp /(tp + fn)

            # compute precision per class 
            precision = tp / (tp + fp)

            # compute F1-measure per class 
            f1 = 2*tp / (2* tp + fp + fn)

            # saving stats : 

            stats['precision'][t] = precision
            stats['recall'][t] = recall
            stats['accuracy'][t] = accuracy
            stats['f1-measure'][t] = f1

        # Compute Average classification rate
        stats = pd.DataFrame(stats).transpose()
        return stats

# %% [markdown]
# ## Evaluation of the Model
# Choice of the sub-task, the dimension of the embedding vectors, and the percentage of validation taken from train.
#
# **Best choice** : `dim_vect = 200` and `pValid = 0.2`

# %%
# 1st step : Define Classifier for specific task
#classifier = OffensiveClassifier(subtask='subtask_a', dim_vect=200 , pValid = 0.2)
#classifier = OffensiveClassifier(subtask='subtask_b', dim_vect=200 , pValid = 0.2)
classifier = OffensiveClassifier(subtask='subtask_c', dim_vect=200 , pValid = 0.2)
# Out:
# ---- Loading the processed GloVe files : Done
# ---- Creating the Pytorch Embedding Layer  : Done
# -- Data Handling :
# ---- Load the Clean Adapted Dataset : Done
# ---- Augmenting the Data :
# Before Augmentation :  {'IND': 1926, 'OTH': 316, 'GRP': 860}
# After Augmentation :  {'IND': 1926, 'OTH': 1926, 'GRP': 1926}

# %% [markdown]
# ### 1) FFNN
# Best Parameters :

# %%
# 2nd Step : Define Model : 
model = FFNN(embedding= classifier.embedding, 
             hidden_dim= 100 ,
             num_classes = classifier.nb_class,
             embedding_dim= classifier.dim_vect)
# Out:
# ------ Creating FFNN : Done

# %%
# 3rd Step : Define Optinizer : 
optimizer = optim.Adam(model.parameters(), lr=0.00001,weight_decay=0.005)

# %%
# 4th Step : Train the Model
classifier.train( nb_epochs= 20,
                       optimizer= optimizer , 
                       model= model ,
                       batch_size= 50)
# Out:
# | Epoch: 00 | Train Loss: 1.084 | Train Acc: 33.35%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.500000  0.101050  0.000000
# recall      0.010395  0.974684  0.000000
# accuracy    0.145648  0.106632  0.275168
# f1-measure  0.020367  0.183115  0.000000
# | Validation Accuracy : 10.59 % - Macro F1 Score : 0.0678
# | CM on the Validation :
# [[  5. 475.   1.]
#  [  1.  77.   1.]
#  [  4. 210.   0.]]
#
# =============================================================================
#
# | Epoch: 01 | Train Loss: 1.167 | Train Acc: 33.11%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.533333  0.099338  0.000000
# recall      0.016632  0.949367  0.000000
# accuracy    0.147425  0.108214  0.275748
# f1-measure  0.032258  0.179856  0.000000
# | Validation Accuracy : 10.72 % - Macro F1 Score : 0.0707
# | CM on the Validation :
# [[  8. 471.   2.]
#  [  2.  75.   2.]
#  [  5. 209.   0.]]
#
# =============================================================================
#
# | Epoch: 02 | Train Loss: 1.204 | Train Acc: 33.39%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.714286  0.101351  0.000000
# recall      0.041580  0.949367  0.000000
# accuracy    0.168440  0.124346  0.301587
# f1-measure  0.078585  0.183150  0.000000
# | Validation Accuracy : 12.27 % - Macro F1 Score : 0.0872
# | CM on the Validation :
# [[ 20. 457.   4.]
#  [  2.  75.   2.]
#  [  6. 208.   0.]]
#
# =============================================================================
#
# | Epoch: 03 | Train Loss: 1.136 | Train Acc: 34.21%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.763158  0.101788  0.222222
# recall      0.060291  0.936709  0.009346
# accuracy    0.185512  0.137615  0.324074
# f1-measure  0.111753  0.183623  0.017937
# | Validation Accuracy : 13.57 % - Macro F1 Score : 0.1044
# | CM on the Validation :
# [[ 29. 448.   4.]
#  [  2.  74.   3.]
#  [  7. 205.   2.]]
#
# =============================================================================
#
# | Epoch: 04 | Train Loss: 1.123 | Train Acc: 35.38%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.783333  0.103693  0.200000
# recall      0.097713  0.924051  0.009346
# accuracy    0.214411  0.160738  0.356725
# f1-measure  0.173752  0.186462  0.017857
# | Validation Accuracy : 15.76 % - Macro F1 Score : 0.1260
# | CM on the Validation :
# [[ 47. 430.   4.]
#  [  2.  73.   4.]
#  [ 11. 201.   2.]]
#
# =============================================================================
#
# | Epoch: 05 | Train Loss: 1.139 | Train Acc: 36.56%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.812500  0.107251  0.250000
# recall      0.162162  0.898734  0.018692
# accuracy    0.266551  0.203457  0.408000
# f1-measure  0.270364  0.191633  0.034783
# | Validation Accuracy : 19.77 % - Macro F1 Score : 0.1656
# | CM on the Validation :
# [[ 78. 396.   7.]
#  [  3.  71.   5.]
#  [ 15. 195.   4.]]
#
# =============================================================================
#
# | Epoch: 06 | Train Loss: 1.071 | Train Acc: 37.78%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.834586  0.115321  0.382353
# recall      0.230769  0.886076  0.060748
# accuracy    0.331058  0.262162  0.466346
# f1-measure  0.361564  0.204082  0.104839
# | Validation Accuracy : 25.06 % - Macro F1 Score : 0.2235
# | CM on the Validation :
# [[111. 355.  15.]
#  [  3.  70.   6.]
#  [ 19. 182.  13.]]
#
# =============================================================================
#
# | Epoch: 07 | Train Loss: 1.090 | Train Acc: 38.75%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.803681  0.109712  0.363636
# recall      0.272349  0.772152  0.093458
# accuracy    0.356902  0.292414  0.480726
# f1-measure  0.406832  0.192126  0.148699
# | Validation Accuracy : 27.39 % - Macro F1 Score : 0.2492
# | CM on the Validation :
# [[131. 327.  23.]
#  [  6.  61.  12.]
#  [ 26. 168.  20.]]
#
# =============================================================================
#
# | Epoch: 08 | Train Loss: 1.088 | Train Acc: 39.57%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.807107  0.108000  0.402597
# recall      0.330561  0.683544  0.144860
# accuracy    0.403974  0.341259  0.515856
# f1-measure  0.469027  0.186528  0.213058
# | Validation Accuracy : 31.52 % - Macro F1 Score : 0.2895
# | CM on the Validation :
# [[159. 293.  29.]
#  [  8.  54.  17.]
#  [ 30. 153.  31.]]
#
# =============================================================================
#
# | Epoch: 09 | Train Loss: 1.054 | Train Acc: 41.37%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.821429  0.106818  0.445455
# recall      0.382536  0.594937  0.228972
# accuracy    0.453809  0.397163  0.553360
# f1-measure  0.521986  0.181118  0.302469
# | Validation Accuracy : 36.18 % - Macro F1 Score : 0.3352
# | CM on the Validation :
# [[184. 260.  37.]
#  [  8.  47.  24.]
#  [ 32. 133.  49.]]
#
# =============================================================================
#
# | Epoch: 10 | Train Loss: 1.063 | Train Acc: 42.66%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.834646  0.117801  0.478261
# recall      0.440748  0.569620  0.308411
# accuracy    0.509464  0.465418  0.594843
# f1-measure  0.576871  0.195228  0.375000
# | Validation Accuracy : 41.73 % - Macro F1 Score : 0.3824
# | CM on the Validation :
# [[212. 222.  47.]
#  [  9.  45.  25.]
#  [ 33. 115.  66.]]
#
# =============================================================================
#
# | Epoch: 11 | Train Loss: 1.046 | Train Acc: 44.67%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.832143  0.124620  0.478788
# recall      0.484407  0.518987  0.369159
# accuracy    0.544753  0.519882  0.614983
# f1-measure  0.612352  0.200980  0.416887
# | Validation Accuracy : 45.61 % - Macro F1 Score : 0.4101
# | CM on the Validation :
# [[233. 189.  59.]
#  [ 11.  41.  27.]
#  [ 36.  99.  79.]]
#
# =============================================================================
#
# | Epoch: 12 | Train Loss: 1.061 | Train Acc: 46.42%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.836735  0.133106  0.491979
# recall      0.511435  0.493671  0.429907
# accuracy    0.571212  0.561848  0.634680
# f1-measure  0.634839  0.209677  0.458853
# | Validation Accuracy : 48.71 % - Macro F1 Score : 0.4345
# | CM on the Validation :
# [[246. 169.  66.]
#  [ 11.  39.  29.]
#  [ 37.  85.  92.]]
#
# =============================================================================
#
# | Epoch: 13 | Train Loss: 1.060 | Train Acc: 48.14%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.836538  0.133080  0.492462
# recall      0.542620  0.443038  0.457944
# accuracy    0.592481  0.591592  0.644845
# f1-measure  0.658260  0.204678  0.474576
# | Validation Accuracy : 50.90 % - Macro F1 Score : 0.4458
# | CM on the Validation :
# [[261. 150.  70.]
#  [ 13.  35.  31.]
#  [ 38.  78.  98.]]
#
# =============================================================================
#
# | Epoch: 14 | Train Loss: 1.023 | Train Acc: 49.12%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.844237  0.127119  0.502304
# recall      0.563410  0.379747  0.509346
# accuracy    0.611940  0.616541  0.658106
# f1-measure  0.675810  0.190476  0.505800
# | Validation Accuracy : 52.97 % - Macro F1 Score : 0.4574
# | CM on the Validation :
# [[271. 136.  74.]
#  [ 15.  30.  34.]
#  [ 35.  70. 109.]]
#
# =============================================================================
#
# | Epoch: 15 | Train Loss: 1.036 | Train Acc: 49.90%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.848024  0.126126  0.497758
# recall      0.580042  0.354430  0.518692
# accuracy    0.623881  0.630468  0.660348
# f1-measure  0.688889  0.186047  0.508009
# | Validation Accuracy : 54.01 % - Macro F1 Score : 0.4610
# | CM on the Validation :
# [[279. 125.  77.]
#  [ 16.  28.  35.]
#  [ 34.  69. 111.]]
#
# =============================================================================
#
# | Epoch: 16 | Train Loss: 1.041 | Train Acc: 50.84%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.848214  0.125604  0.497835
# recall      0.592516  0.329114  0.537383
# accuracy    0.632987  0.645455  0.664587
# f1-measure  0.697674  0.181818  0.516854
# | Validation Accuracy : 55.04 % - Macro F1 Score : 0.4654
# | CM on the Validation :
# [[285. 117.  79.]
#  [ 16.  26.  37.]
#  [ 35.  64. 115.]]
#
# =============================================================================
# | Epoch: 17 | Train Loss: 1.059 | Train Acc: 51.38%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.849558  0.124378  0.495726
# recall      0.598753  0.316456  0.542056
# accuracy    0.637444  0.650986  0.665116
# f1-measure  0.702439  0.178571  0.517857
# | Validation Accuracy : 55.43 % - Macro F1 Score : 0.4663
# | CM on the Validation :
# [[288. 113.  80.]
#  [ 16.  25.  38.]
#  [ 35.  63. 116.]]
#
# =============================================================================
#
# | Epoch: 18 | Train Loss: 1.006 | Train Acc: 52.03%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.856305  0.128205  0.508403
# recall      0.607069  0.316456  0.565421
# accuracy    0.647929  0.661631  0.675926
# f1-measure  0.710462  0.182482  0.535398
# | Validation Accuracy : 56.59 % - Macro F1 Score : 0.4761
# | CM on the Validation :
# [[292. 110.  79.]
#  [ 16.  25.  38.]
#  [ 33.  60. 121.]]
#
# =============================================================================
#
# | Epoch: 19 | Train Loss: 1.039 | Train Acc: 51.75%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.857550  0.139037  0.512712
# recall      0.625780  0.329114  0.565421
# accuracy    0.660767  0.676737  0.682927
# f1-measure  0.723558  0.195489  0.537778
# | Validation Accuracy : 57.88 % - Macro F1 Score : 0.4856
# | CM on the Validation :
# [[301. 101.  79.]
#  [ 17.  26.  36.]
#  [ 33.  60. 121.]]
#
# =============================================================================

# %%
# 5th Step : Test the Model and save data 
classifier.test(folder='FFNN')
# Out:
# | Successfully save to :  ../data/results/FFNN/subtask_c.csv

# %% [markdown]
# ### 2) CNN : 1 Layer
# Best Parameters :

# %%
# 2nd Step : Define Model : 
model = CNN( embedding= classifier.embedding, 
             embedding_dim = classifier.dim_vect,
             out_channels= 150,
             window_size= 3,
             output_dim= classifier.nb_class,
             dropout = 0.5)

# %%
# 3rd Step : Define Optinizer : 
optimizer = optim.Adam(model.parameters(), lr=0.00001,weight_decay=0.005)
#optimizer = optim.RMSprop(model.parameters(), lr=0.001,weight_decay=0.001)

# %%
# 4th Step : Train the Model
classifier.train( nb_epochs= 50,
                       optimizer= optimizer , 
                       model= model ,
                       batch_size= 20)
# Out:
# | Epoch: 00 | Train Loss: 1.044 | Train Acc: 34.57%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.888889  0.160000  0.283174
# recall      0.033264  0.050633  0.967290
# accuracy    0.327089  0.702786  0.299472
# f1-measure  0.064128  0.076923  0.438095
# | Validation Accuracy : 29.33 % - Macro F1 Score : 0.1930
# | CM on the Validation :
# [[ 16.  16. 449.]
#  [  0.   4.  75.]
#  [  2.   5. 207.]]
#
# =============================================================================
#
# | Epoch: 01 | Train Loss: 1.232 | Train Acc: 37.00%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.861538  0.089888  0.329730
# recall      0.232848  0.101266  0.855140
# accuracy    0.439130  0.665934  0.429178
# f1-measure  0.366612  0.095238  0.475943
# | Validation Accuracy : 39.15 % - Macro F1 Score : 0.3126
# | CM on the Validation :
# [[112.  65. 304.]
#  [  3.   8.  68.]
#  [ 15.  16. 183.]]
#
# =============================================================================
#
# | Epoch: 02 | Train Loss: 1.117 | Train Acc: 39.19%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.844898  0.117117  0.375598
# recall      0.430353  0.164557  0.733645
# accuracy    0.547170  0.696858  0.542446
# f1-measure  0.570248  0.136842  0.496835
# | Validation Accuracy : 48.71 % - Macro F1 Score : 0.4013
# | CM on the Validation :
# [[207.  69. 205.]
#  [ 10.  13.  56.]
#  [ 28.  29. 157.]]
#
# =============================================================================
#
# | Epoch: 03 | Train Loss: 1.055 | Train Acc: 41.13%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.847973  0.133333  0.396783
# recall      0.521830  0.177215  0.691589
# accuracy    0.600291  0.725835  0.586648
# f1-measure  0.646075  0.152174  0.504259
# | Validation Accuracy : 53.36 % - Macro F1 Score : 0.4342
# | CM on the Validation :
# [[251.  58. 172.]
#  [ 12.  14.  53.]
#  [ 33.  33. 148.]]
#
# =============================================================================
#
# | Epoch: 04 | Train Loss: 1.037 | Train Acc: 43.06%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.837278  0.159574  0.429825
# recall      0.588358  0.189873  0.686916
# accuracy    0.637536  0.756803  0.629420
# f1-measure  0.691087  0.173410  0.528777
# | Validation Accuracy : 57.49 % - Macro F1 Score : 0.4644
# | CM on the Validation :
# [[283.  50. 148.]
#  [ 17.  15.  47.]
#  [ 38.  29. 147.]]
#
# =============================================================================
#
# | Epoch: 05 | Train Loss: 0.998 | Train Acc: 46.11%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.841499  0.157303  0.449704
# recall      0.607069  0.177215  0.710280
# accuracy    0.652422  0.765886  0.648725
# f1-measure  0.705314  0.166667  0.550725
# | Validation Accuracy : 59.17 % - Macro F1 Score : 0.4742
# | CM on the Validation :
# [[292.  50. 139.]
#  [ 18.  14.  47.]
#  [ 37.  25. 152.]]
#
# =============================================================================
#
# | Epoch: 06 | Train Loss: 1.176 | Train Acc: 47.48%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.849432  0.154639  0.473846
# recall      0.621622  0.189873  0.719626
# accuracy    0.665718  0.762215  0.669528
# f1-measure  0.717887  0.170455  0.571429
# | Validation Accuracy : 60.47 % - Macro F1 Score : 0.4866
# | CM on the Validation :
# [[299.  55. 127.]
#  [ 20.  15.  44.]
#  [ 33.  27. 154.]]
#
# =============================================================================
#
# | Epoch: 07 | Train Loss: 0.928 | Train Acc: 49.50%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.847222  0.144231  0.490323
# recall      0.634096  0.189873  0.710280
# accuracy    0.671408  0.755200  0.682081
# f1-measure  0.725327  0.163934  0.580153
# | Validation Accuracy : 60.98 % - Macro F1 Score : 0.4898
# | CM on the Validation :
# [[305.  60. 116.]
#  [ 22.  15.  42.]
#  [ 33.  29. 152.]]
#
# =============================================================================
#
# | Epoch: 08 | Train Loss: 0.882 | Train Acc: 51.58%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.836512  0.132653  0.491909
# recall      0.638254  0.164557  0.710280
# accuracy    0.668555  0.757624  0.683068
# f1-measure  0.724057  0.146893  0.581262
# | Validation Accuracy : 60.98 % - Macro F1 Score : 0.4841
# | CM on the Validation :
# [[307.  57. 117.]
#  [ 26.  13.  40.]
#  [ 34.  28. 152.]]
#
# =============================================================================
#
# | Epoch: 09 | Train Loss: 1.018 | Train Acc: 52.14%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.833780  0.136842  0.490196
# recall      0.646570  0.164557  0.700935
# accuracy    0.671388  0.762058  0.682997
# f1-measure  0.728337  0.149425  0.576923
# | Validation Accuracy : 61.24 % - Macro F1 Score : 0.4849
# | CM on the Validation :
# [[311.  53. 117.]
#  [ 27.  13.  39.]
#  [ 35.  29. 150.]]
#
# =============================================================================
#
# | Epoch: 10 | Train Loss: 0.958 | Train Acc: 52.84%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.833333  0.144231  0.506993
# recall      0.665281  0.189873  0.677570
# accuracy    0.680851  0.758294  0.695652
# f1-measure  0.739884  0.163934  0.580000
# | Validation Accuracy : 62.02 % - Macro F1 Score : 0.4946
# | CM on the Validation :
# [[320.  57. 104.]
#  [ 27.  15.  37.]
#  [ 37.  32. 145.]]
#
# =============================================================================
#
# | Epoch: 11 | Train Loss: 0.911 | Train Acc: 54.78%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.828205  0.145631  0.508897
# recall      0.671518  0.189873  0.668224
# accuracy    0.681303  0.759874  0.697101
# f1-measure  0.741676  0.164835  0.577778
# | Validation Accuracy : 62.14 % - Macro F1 Score : 0.4948
# | CM on the Validation :
# [[323.  57. 101.]
#  [ 27.  15.  37.]
#  [ 40.  31. 143.]]
#
# =============================================================================
#
# | Epoch: 12 | Train Loss: 0.968 | Train Acc: 54.48%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.826972  0.151515  0.503546
# recall      0.675676  0.189873  0.663551
# accuracy    0.682720  0.765079  0.694524
# f1-measure  0.743707  0.168539  0.572581
# | Validation Accuracy : 62.27 % - Macro F1 Score : 0.4949
# | CM on the Validation :
# [[325.  53. 103.]
#  [ 27.  15.  37.]
#  [ 41.  31. 142.]]
#
# =============================================================================
#
# | Epoch: 13 | Train Loss: 0.983 | Train Acc: 56.32%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.826873  0.152381  0.500000
# recall      0.665281  0.202532  0.658879
# accuracy    0.676596  0.758347  0.690304
# f1-measure  0.737327  0.173913  0.568548
# | Validation Accuracy : 61.63 % - Macro F1 Score : 0.4933
# | CM on the Validation :
# [[320.  56. 105.]
#  [ 27.  16.  36.]
#  [ 40.  33. 141.]]
#
# =============================================================================
#
# | Epoch: 14 | Train Loss: 0.979 | Train Acc: 57.30%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.822785  0.161616  0.503571
# recall      0.675676  0.202532  0.658879
# accuracy    0.680791  0.767516  0.694524
# f1-measure  0.742009  0.179775  0.570850
# | Validation Accuracy : 62.27 % - Macro F1 Score : 0.4975
# | CM on the Validation :
# [[325.  52. 104.]
#  [ 28.  16.  35.]
#  [ 42.  31. 141.]]
#
# =============================================================================
#
# | Epoch: 15 | Train Loss: 0.905 | Train Acc: 58.20%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.822785  0.153846  0.505455
# recall      0.675676  0.202532  0.649533
# accuracy    0.679887  0.760697  0.694645
# f1-measure  0.742009  0.174863  0.568507
# | Validation Accuracy : 62.02 % - Macro F1 Score : 0.4951
# | CM on the Validation :
# [[325.  55. 101.]
#  [ 28.  16.  35.]
#  [ 42.  33. 139.]]
#
# =============================================================================
#
# | Epoch: 16 | Train Loss: 0.750 | Train Acc: 58.12%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.823678  0.150943  0.509225
# recall      0.679834  0.202532  0.644860
# accuracy    0.682270  0.758675  0.697101
# f1-measure  0.744875  0.172973  0.569072
# | Validation Accuracy : 62.14 % - Macro F1 Score : 0.4956
# | CM on the Validation :
# [[327.  56.  98.]
#  [ 28.  16.  35.]
#  [ 42.  34. 138.]]
#
# =============================================================================
# | Epoch: 17 | Train Loss: 0.861 | Train Acc: 59.33%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.822055  0.152381  0.511111
# recall      0.681913  0.202532  0.644860
# accuracy    0.682720  0.760252  0.698551
# f1-measure  0.745455  0.173913  0.570248
# | Validation Accuracy : 62.27 % - Macro F1 Score : 0.4965
# | CM on the Validation :
# [[328.  56.  97.]
#  [ 28.  16.  35.]
#  [ 43.  33. 138.]]
#
# =============================================================================
#
# | Epoch: 18 | Train Loss: 0.916 | Train Acc: 59.66%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.822500  0.144144  0.513308
# recall      0.683992  0.202532  0.630841
# accuracy    0.682788  0.752351  0.698690
# f1-measure  0.746879  0.168421  0.566038
# | Validation Accuracy : 62.02 % - Macro F1 Score : 0.4938
# | CM on the Validation :
# [[329.  59.  93.]
#  [ 28.  16.  35.]
#  [ 43.  36. 135.]]
#
# =============================================================================
#
# | Epoch: 19 | Train Loss: 0.979 | Train Acc: 59.92%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.824121  0.146552  0.519231
# recall      0.681913  0.215190  0.630841
# accuracy    0.682788  0.748830  0.701754
# f1-measure  0.746303  0.174359  0.569620
# | Validation Accuracy : 62.02 % - Macro F1 Score : 0.4968
# | CM on the Validation :
# [[328.  62.  91.]
#  [ 28.  17.  34.]
#  [ 42.  37. 135.]]
#
# =============================================================================
#
# | Epoch: 20 | Train Loss: 1.091 | Train Acc: 60.90%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.823383  0.154545  0.519084
# recall      0.688150  0.215190  0.635514
# accuracy    0.686525  0.757433  0.703488
# f1-measure  0.749717  0.179894  0.571429
# | Validation Accuracy : 62.53 % - Macro F1 Score : 0.5003
# | CM on the Validation :
# [[331.  58.  92.]
#  [ 28.  17.  34.]
#  [ 43.  35. 136.]]
#
# =============================================================================
#
# | Epoch: 21 | Train Loss: 0.850 | Train Acc: 60.90%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.822222  0.153153  0.519380
# recall      0.692308  0.215190  0.626168
# accuracy    0.687500  0.756250  0.703488
# f1-measure  0.751693  0.178947  0.567797
# | Validation Accuracy : 62.53 % - Macro F1 Score : 0.4995
# | CM on the Validation :
# [[333.  58.  90.]
#  [ 28.  17.  34.]
#  [ 44.  36. 134.]]
#
# =============================================================================
#
# | Epoch: 22 | Train Loss: 0.812 | Train Acc: 61.41%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.823096  0.157407  0.521236
# recall      0.696466  0.215190  0.630841
# accuracy    0.690780  0.760938  0.705797
# f1-measure  0.754505  0.181818  0.570825
# | Validation Accuracy : 62.92 % - Macro F1 Score : 0.5024
# | CM on the Validation :
# [[335.  56.  90.]
#  [ 28.  17.  34.]
#  [ 44.  35. 135.]]
#
# =============================================================================
#
# | Epoch: 23 | Train Loss: 0.899 | Train Acc: 61.78%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.822222  0.149123  0.521569
# recall      0.692308  0.215190  0.621495
# accuracy    0.687055  0.752336  0.704082
# f1-measure  0.751693  0.176166  0.567164
# | Validation Accuracy : 62.40 % - Macro F1 Score : 0.4983
# | CM on the Validation :
# [[333.  60.  88.]
#  [ 28.  17.  34.]
#  [ 44.  37. 133.]]
#
# =============================================================================
#
# | Epoch: 24 | Train Loss: 0.812 | Train Acc: 62.41%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.824257  0.146552  0.523622
# recall      0.692308  0.215190  0.621495
# accuracy    0.688034  0.750000  0.705109
# f1-measure  0.752542  0.174359  0.568376
# | Validation Accuracy : 62.40 % - Macro F1 Score : 0.4984
# | CM on the Validation :
# [[333.  61.  87.]
#  [ 28.  17.  34.]
#  [ 43.  38. 133.]]
#
# =============================================================================
#
# | Epoch: 25 | Train Loss: 0.865 | Train Acc: 62.08%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.823096  0.146552  0.525896
# recall      0.696466  0.215190  0.616822
# accuracy    0.689459  0.750388  0.706569
# f1-measure  0.754505  0.174359  0.567742
# | Validation Accuracy : 62.53 % - Macro F1 Score : 0.4989
# | CM on the Validation :
# [[335.  61.  85.]
#  [ 28.  17.  34.]
#  [ 44.  38. 132.]]
#
# =============================================================================
#
# | Epoch: 26 | Train Loss: 1.008 | Train Acc: 63.49%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.827160  0.154472  0.528455
# recall      0.696466  0.240506  0.607477
# accuracy    0.691429  0.746914  0.707602
# f1-measure  0.756208  0.188119  0.565217
# | Validation Accuracy : 62.53 % - Macro F1 Score : 0.5032
# | CM on the Validation :
# [[335.  63.  83.]
#  [ 27.  19.  33.]
#  [ 43.  41. 130.]]
#
# =============================================================================
#
# | Epoch: 27 | Train Loss: 0.814 | Train Acc: 63.92%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.828784  0.150000  0.525896
# recall      0.694387  0.227848  0.616822
# accuracy    0.691429  0.748068  0.706569
# f1-measure  0.755656  0.180905  0.567742
# | Validation Accuracy : 62.53 % - Macro F1 Score : 0.5014
# | CM on the Validation :
# [[334.  62.  85.]
#  [ 27.  18.  34.]
#  [ 42.  40. 132.]]
#
# =============================================================================
#
# | Epoch: 28 | Train Loss: 0.815 | Train Acc: 63.87%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.828784  0.146341  0.524194
# recall      0.694387  0.227848  0.607477
# accuracy    0.690544  0.743827  0.704678
# f1-measure  0.755656  0.178218  0.562771
# | Validation Accuracy : 62.27 % - Macro F1 Score : 0.4989
# | CM on the Validation :
# [[334.  63.  84.]
#  [ 27.  18.  34.]
#  [ 42.  42. 130.]]
#
# =============================================================================
#
# | Epoch: 29 | Train Loss: 0.764 | Train Acc: 63.94%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.827160  0.152000  0.528689
# recall      0.696466  0.240506  0.602804
# accuracy    0.690987  0.744222  0.707174
# f1-measure  0.756208  0.186275  0.563319
# | Validation Accuracy : 62.40 % - Macro F1 Score : 0.5019
# | CM on the Validation :
# [[335.  64.  82.]
#  [ 27.  19.  33.]
#  [ 43.  42. 129.]]
#
# =============================================================================
#
# | Epoch: 30 | Train Loss: 0.937 | Train Acc: 64.69%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.827586  0.147541  0.524390
# recall      0.698545  0.227848  0.602804
# accuracy    0.691977  0.745370  0.705109
# f1-measure  0.757610  0.179104  0.560870
# | Validation Accuracy : 62.40 % - Macro F1 Score : 0.4992
# | CM on the Validation :
# [[336.  62.  83.]
#  [ 27.  18.  34.]
#  [ 43.  42. 129.]]
#
# =============================================================================
#
# | Epoch: 31 | Train Loss: 0.836 | Train Acc: 64.69%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.828010  0.153846  0.528000
# recall      0.700624  0.227848  0.616822
# accuracy    0.694722  0.752705  0.708879
# f1-measure  0.759009  0.183673  0.568966
# | Validation Accuracy : 62.92 % - Macro F1 Score : 0.5039
# | CM on the Validation :
# [[337.  60.  84.]
#  [ 27.  18.  34.]
#  [ 43.  39. 132.]]
#
# =============================================================================
#
# | Epoch: 32 | Train Loss: 0.864 | Train Acc: 65.23%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.825980  0.158333  0.528455
# recall      0.700624  0.240506  0.607477
# accuracy    0.693295  0.751159  0.708455
# f1-measure  0.758155  0.190955  0.565217
# | Validation Accuracy : 62.79 % - Macro F1 Score : 0.5048
# | CM on the Validation :
# [[337.  61.  83.]
#  [ 27.  19.  33.]
#  [ 44.  40. 130.]]
#
# =============================================================================
#
# | Epoch: 33 | Train Loss: 0.787 | Train Acc: 65.97%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.826406  0.165289  0.532787
# recall      0.702703  0.253165  0.607477
# accuracy    0.695157  0.753086  0.711370
# f1-measure  0.759551  0.200000  0.567686
# | Validation Accuracy : 63.05 % - Macro F1 Score : 0.5091
# | CM on the Validation :
# [[338.  61.  82.]
#  [ 27.  20.  32.]
#  [ 44.  40. 130.]]
#
# =============================================================================
# | Epoch: 34 | Train Loss: 0.724 | Train Acc: 66.44%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.827251  0.175000  0.534979
# recall      0.706861  0.265823  0.607477
# accuracy    0.698435  0.757716  0.713663
# f1-measure  0.762332  0.211055  0.568928
# | Validation Accuracy : 63.44 % - Macro F1 Score : 0.5141
# | CM on the Validation :
# [[340.  59.  82.]
#  [ 27.  21.  31.]
#  [ 44.  40. 130.]]
#
# =============================================================================
#
# | Epoch: 35 | Train Loss: 0.795 | Train Acc: 66.14%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.826829  0.173554  0.534979
# recall      0.704782  0.265823  0.607477
# accuracy    0.697013  0.756173  0.713246
# f1-measure  0.760943  0.210000  0.568928
# | Validation Accuracy : 63.31 % - Macro F1 Score : 0.5133
# | CM on the Validation :
# [[339.  60.  82.]
#  [ 27.  21.  31.]
#  [ 44.  40. 130.]]
#
# =============================================================================
#
# | Epoch: 36 | Train Loss: 1.053 | Train Acc: 66.83%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.828851  0.173554  0.536885
# recall      0.704782  0.265823  0.612150
# accuracy    0.698435  0.756549  0.714702
# f1-measure  0.761798  0.210000  0.572052
# | Validation Accuracy : 63.44 % - Macro F1 Score : 0.5146
# | CM on the Validation :
# [[339.  60.  82.]
#  [ 27.  21.  31.]
#  [ 43.  40. 131.]]
#
# =============================================================================
#
# | Epoch: 37 | Train Loss: 0.832 | Train Acc: 67.46%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.828087  0.170940  0.532787
# recall      0.711019  0.253165  0.607477
# accuracy    0.700855  0.759259  0.713043
# f1-measure  0.765101  0.204082  0.567686
# | Validation Accuracy : 63.57 % - Macro F1 Score : 0.5123
# | CM on the Validation :
# [[342.  57.  82.]
#  [ 27.  20.  32.]
#  [ 44.  40. 130.]]
#
# =============================================================================
#
# | Epoch: 38 | Train Loss: 0.871 | Train Acc: 66.67%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.828087  0.165217  0.528455
# recall      0.711019  0.240506  0.607477
# accuracy    0.700428  0.758887  0.710564
# f1-measure  0.765101  0.195876  0.565217
# | Validation Accuracy : 63.44 % - Macro F1 Score : 0.5087
# | CM on the Validation :
# [[342.  56.  83.]
#  [ 27.  19.  33.]
#  [ 44.  40. 130.]]
#
# =============================================================================
#
# | Epoch: 39 | Train Loss: 0.640 | Train Acc: 67.94%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.827670  0.169492  0.532787
# recall      0.708940  0.253165  0.607477
# accuracy    0.699430  0.757716  0.712627
# f1-measure  0.763718  0.203046  0.567686
# | Validation Accuracy : 63.44 % - Macro F1 Score : 0.5115
# | CM on the Validation :
# [[341.  58.  82.]
#  [ 27.  20.  32.]
#  [ 44.  40. 130.]]
#
# =============================================================================
#
# | Epoch: 40 | Train Loss: 0.791 | Train Acc: 68.76%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.829268  0.170732  0.535270
# recall      0.706861  0.265823  0.602804
# accuracy    0.699001  0.753846  0.713246
# f1-measure  0.763187  0.207921  0.567033
# | Validation Accuracy : 63.31 % - Macro F1 Score : 0.5127
# | CM on the Validation :
# [[340.  60.  81.]
#  [ 27.  21.  31.]
#  [ 43.  42. 129.]]
#
# =============================================================================
#
# | Epoch: 41 | Train Loss: 0.728 | Train Acc: 68.90%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.828087  0.170732  0.533613
# recall      0.711019  0.265823  0.593458
# accuracy    0.700000  0.753846  0.712209
# f1-measure  0.765101  0.207921  0.561947
# | Validation Accuracy : 63.31 % - Macro F1 Score : 0.5117
# | CM on the Validation :
# [[342.  59.  80.]
#  [ 27.  21.  31.]
#  [ 44.  43. 127.]]
#
# =============================================================================
#
# | Epoch: 42 | Train Loss: 0.772 | Train Acc: 69.02%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.828087  0.170940  0.528689
# recall      0.711019  0.253165  0.602804
# accuracy    0.700428  0.758887  0.710564
# f1-measure  0.765101  0.204082  0.563319
# | Validation Accuracy : 63.44 % - Macro F1 Score : 0.5108
# | CM on the Validation :
# [[342.  56.  83.]
#  [ 27.  20.  32.]
#  [ 44.  41. 129.]]
#
# =============================================================================
#
# | Epoch: 43 | Train Loss: 0.790 | Train Acc: 69.78%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.832924  0.160000  0.533058
# recall      0.704782  0.253165  0.602804
# accuracy    0.699140  0.748466  0.711370
# f1-measure  0.763514  0.196078  0.565789
# | Validation Accuracy : 63.05 % - Macro F1 Score : 0.5085
# | CM on the Validation :
# [[339.  61.  81.]
#  [ 27.  20.  32.]
#  [ 41.  44. 129.]]
#
# =============================================================================
#
# | Epoch: 44 | Train Loss: 0.770 | Train Acc: 68.42%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.834951  0.172414  0.532520
# recall      0.715177  0.253165  0.612150
# accuracy    0.707143  0.761538  0.714286
# f1-measure  0.770437  0.205128  0.569565
# | Validation Accuracy : 63.95 % - Macro F1 Score : 0.5150
# | CM on the Validation :
# [[344.  54.  83.]
#  [ 27.  20.  32.]
#  [ 41.  42. 131.]]
#
# =============================================================================
#
# | Epoch: 45 | Train Loss: 0.815 | Train Acc: 69.80%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.832524  0.169492  0.528689
# recall      0.713098  0.253165  0.602804
# accuracy    0.703863  0.758089  0.710983
# f1-measure  0.768197  0.203046  0.563319
# | Validation Accuracy : 63.57 % - Macro F1 Score : 0.5115
# | CM on the Validation :
# [[343.  55.  83.]
#  [ 27.  20.  32.]
#  [ 42.  43. 129.]]
#
# =============================================================================
#
# | Epoch: 46 | Train Loss: 0.909 | Train Acc: 70.12%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.832930  0.166667  0.535270
# recall      0.715177  0.253165  0.602804
# accuracy    0.705293  0.756135  0.714493
# f1-measure  0.769575  0.201005  0.567033
# | Validation Accuracy : 63.70 % - Macro F1 Score : 0.5125
# | CM on the Validation :
# [[344.  57.  80.]
#  [ 27.  20.  32.]
#  [ 42.  43. 129.]]
#
# =============================================================================
#
# | Epoch: 47 | Train Loss: 0.730 | Train Acc: 70.32%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.830918  0.172414  0.532787
# recall      0.715177  0.253165  0.607477
# accuracy    0.704708  0.761171  0.713873
# f1-measure  0.768715  0.205128  0.567686
# | Validation Accuracy : 63.82 % - Macro F1 Score : 0.5138
# | CM on the Validation :
# [[344.  55.  82.]
#  [ 27.  20.  32.]
#  [ 43.  41. 130.]]
#
# =============================================================================
#
# | Epoch: 48 | Train Loss: 0.879 | Train Acc: 70.70%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.830144  0.175439  0.533058
# recall      0.721414  0.253165  0.602804
# accuracy    0.707561  0.764253  0.714697
# f1-measure  0.771969  0.207254  0.565789
# | Validation Accuracy : 64.08 % - Macro F1 Score : 0.5150
# | CM on the Validation :
# [[347.  53.  81.]
#  [ 27.  20.  32.]
#  [ 44.  41. 129.]]
#
# =============================================================================
#
# | Epoch: 49 | Train Loss: 0.825 | Train Acc: 71.53%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.836145  0.162162  0.532258
# recall      0.721414  0.227848  0.616822
# accuracy    0.711016  0.763441  0.715108
# f1-measure  0.774554  0.189474  0.571429
# | Validation Accuracy : 64.21 % - Macro F1 Score : 0.5118
# | CM on the Validation :
# [[347.  52.  82.]
#  [ 27.  18.  34.]
#  [ 41.  41. 132.]]
#
# =============================================================================

# %%
# 5th Step : Test the Model and save data 
classifier.test(folder='CNN')
# Out:
# | Successfully save to :  ../data/results/CNN/subtask_c.csv

# %% [markdown]
# ### 3) CNN : 3 Layers
# Best Parameters :
# CNN_paper : nb epoch 3, batch_size= 20, best f1 for A : 0.75 optimizer = optim.Adam(model.parameters(), lr=0.0001,weight_decay=0.005)

# %%
# 2nd Step : Define Model : 
model = CNN_paper(embedding= classifier.embedding, 
             embedding_dim = classifier.dim_vect,
             out_channels= 100,
             window_size= [3,4,5],
             output_dim= classifier.nb_class,
             dropout = 0.5)

# %%
# 3rd Step : Define Optinizer : 
optimizer = optim.Adam(model.parameters(), lr=0.0001,weight_decay=0.01)

# %%
# 4th Step : Train the Model
classifier.train( nb_epochs= 20,
                       optimizer= optimizer , 
                       model= model ,
                       batch_size= 50)
# Out:
# | Epoch: 00 | Train Loss: 0.957 | Train Acc: 44.02%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.871560  0.174825  0.450658
# recall      0.592516  0.316456  0.640187
# accuracy    0.652555  0.722132  0.646889
# f1-measure  0.705446  0.225225  0.528958
# | Validation Accuracy : 57.75 % - Macro F1 Score : 0.4865
# | CM on the Validation :
# [[285.  72. 124.]
#  [ 11.  25.  43.]
#  [ 31.  46. 137.]]
#
# =============================================================================
#
# | Epoch: 01 | Train Loss: 0.945 | Train Acc: 58.73%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.840541  0.144509  0.515152
# recall      0.646570  0.316456  0.556075
# accuracy    0.665205  0.692542  0.687311
# f1-measure  0.730905  0.198413  0.534831
# | Validation Accuracy : 58.79 % - Macro F1 Score : 0.4880
# | CM on the Validation :
# [[311.  92.  78.]
#  [ 20.  25.  34.]
#  [ 39.  56. 119.]]
#
# =============================================================================
#
# | Epoch: 02 | Train Loss: 0.813 | Train Acc: 64.54%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.820896  0.152941  0.491289
# recall      0.686071  0.164557  0.658879
# accuracy    0.684583  0.778135  0.688478
# f1-measure  0.747452  0.158537  0.562874
# | Validation Accuracy : 62.53 % - Macro F1 Score : 0.4896
# | CM on the Validation :
# [[330.  45. 106.]
#  [ 26.  13.  40.]
#  [ 46.  27. 141.]]
#
# =============================================================================
#
# | Epoch: 03 | Train Loss: 0.909 | Train Acc: 67.63%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.827068  0.165049  0.507353
# recall      0.686071  0.215190  0.644860
# accuracy    0.687943  0.766193  0.697842
# f1-measure  0.750000  0.186813  0.567901
# | Validation Accuracy : 62.66 % - Macro F1 Score : 0.5016
# | CM on the Validation :
# [[330.  54.  97.]
#  [ 25.  17.  37.]
#  [ 44.  32. 138.]]
#
# =============================================================================
#
# | Epoch: 04 | Train Loss: 0.736 | Train Acc: 71.46%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.828010  0.168000  0.524793
# recall      0.700624  0.265823  0.593458
# accuracy    0.693848  0.749614  0.705968
# f1-measure  0.759009  0.205882  0.557018
# | Validation Accuracy : 62.66 % - Macro F1 Score : 0.5073
# | CM on the Validation :
# [[337.  63.  81.]
#  [ 24.  21.  34.]
#  [ 46.  41. 127.]]
#
# =============================================================================
#
# | Epoch: 05 | Train Loss: 0.855 | Train Acc: 74.54%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.821596  0.182796  0.525490
# recall      0.727651  0.215190  0.626168
# accuracy    0.707627  0.784038  0.713675
# f1-measure  0.771775  0.197674  0.571429
# | Validation Accuracy : 64.73 % - Macro F1 Score : 0.5136
# | CM on the Validation :
# [[350.  46.  85.]
#  [ 26.  17.  36.]
#  [ 50.  30. 134.]]
#
# =============================================================================
#
# | Epoch: 06 | Train Loss: 0.661 | Train Acc: 77.51%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.834928  0.181034  0.541667
# recall      0.725572  0.265823  0.607477
# accuracy    0.713267  0.765697  0.720461
# f1-measure  0.776418  0.215385  0.572687
# | Validation Accuracy : 64.60 % - Macro F1 Score : 0.5215
# | CM on the Validation :
# [[349.  55.  77.]
#  [ 25.  21.  33.]
#  [ 44.  40. 130.]]
#
# =============================================================================
#
# | Epoch: 07 | Train Loss: 0.663 | Train Acc: 79.88%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.832936  0.180952  0.536000
# recall      0.725572  0.240506  0.626168
# accuracy    0.713068  0.774691  0.719198
# f1-measure  0.775556  0.206522  0.577586
# | Validation Accuracy : 64.86 % - Macro F1 Score : 0.5199
# | CM on the Validation :
# [[349.  50.  82.]
#  [ 26.  19.  34.]
#  [ 44.  36. 134.]]
#
# =============================================================================
#
# | Epoch: 08 | Train Loss: 0.578 | Train Acc: 81.35%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.837264  0.195402  0.532319
# recall      0.738046  0.215190  0.654206
# accuracy    0.724187  0.795031  0.722144
# f1-measure  0.784530  0.204819  0.587002
# | Validation Accuracy : 66.15 % - Macro F1 Score : 0.5255
# | CM on the Validation :
# [[355.  39.  87.]
#  [ 26.  17.  36.]
#  [ 43.  31. 140.]]
#
# =============================================================================
#
# | Epoch: 09 | Train Loss: 0.576 | Train Acc: 83.36%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.837209  0.200000  0.537879
# recall      0.748441  0.202532  0.663551
# accuracy    0.730606  0.803101  0.727528
# f1-measure  0.790340  0.201258  0.594142
# | Validation Accuracy : 66.93 % - Macro F1 Score : 0.5286
# | CM on the Validation :
# [[360.  35.  86.]
#  [ 27.  16.  36.]
#  [ 43.  29. 142.]]
#
# =============================================================================
#
# | Epoch: 10 | Train Loss: 0.493 | Train Acc: 84.93%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.858881  0.200000  0.530201
# recall      0.733888  0.164557  0.738318
# accuracy    0.738028  0.816199  0.727778
# f1-measure  0.791480  0.180556  0.617188
# | Validation Accuracy : 67.70 % - Macro F1 Score : 0.5297
# | CM on the Validation :
# [[353.  30.  98.]
#  [ 24.  13.  42.]
#  [ 34.  22. 158.]]
#
# =============================================================================
#
# | Epoch: 11 | Train Loss: 0.432 | Train Acc: 86.13%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.832589  0.220339  0.546816
# recall      0.775468  0.164557  0.682243
# accuracy    0.744056  0.826087  0.737864
# f1-measure  0.803014  0.188406  0.607069
# | Validation Accuracy : 68.73 % - Macro F1 Score : 0.5328
# | CM on the Validation :
# [[373.  25.  83.]
#  [ 28.  13.  38.]
#  [ 47.  21. 146.]]
#
# =============================================================================
#
# | Epoch: 12 | Train Loss: 0.390 | Train Acc: 87.20%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.842956  0.205479  0.541045
# recall      0.758836  0.189873  0.677570
# accuracy    0.740480  0.811437  0.732218
# f1-measure  0.798687  0.197368  0.601660
# | Validation Accuracy : 67.83 % - Macro F1 Score : 0.5326
# | CM on the Validation :
# [[365.  30.  86.]
#  [ 27.  15.  37.]
#  [ 41.  28. 145.]]
#
# =============================================================================
#
# | Epoch: 13 | Train Loss: 0.416 | Train Acc: 88.32%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.841379  0.193548  0.537906
# recall      0.760915  0.151899  0.696262
# accuracy    0.741210  0.818323  0.731944
# f1-measure  0.799127  0.170213  0.606925
# | Validation Accuracy : 68.09 % - Macro F1 Score : 0.5254
# | CM on the Validation :
# [[366.  26.  89.]
#  [ 28.  12.  39.]
#  [ 41.  24. 149.]]
#
# =============================================================================
#
# | Epoch: 14 | Train Loss: 0.525 | Train Acc: 89.20%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.837838  0.263158  0.537671
# recall      0.773389  0.126582  0.733645
# accuracy    0.748611  0.847484  0.737346
# f1-measure  0.804324  0.170940  0.620553
# | Validation Accuracy : 69.64 % - Macro F1 Score : 0.5319
# | CM on the Validation :
# [[372.  16.  93.]
#  [ 27.  10.  42.]
#  [ 45.  12. 157.]]
#
# =============================================================================
#
# | Epoch: 15 | Train Loss: 0.458 | Train Acc: 89.96%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.810309  0.239130  0.563786
# recall      0.817048  0.139241  0.640187
# accuracy    0.750347  0.840062  0.747238
# f1-measure  0.813665  0.176000  0.599562
# | Validation Accuracy : 69.90 % - Macro F1 Score : 0.5297
# | CM on the Validation :
# [[393.  18.  70.]
#  [ 32.  11.  36.]
#  [ 60.  17. 137.]]
#
# =============================================================================
#
# | Epoch: 16 | Train Loss: 0.410 | Train Acc: 90.17%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.829322  0.263158  0.548387
# recall      0.787942  0.126582  0.714953
# accuracy    0.750693  0.848200  0.743484
# f1-measure  0.808102  0.170940  0.620690
# | Validation Accuracy : 70.03 % - Macro F1 Score : 0.5332
# | CM on the Validation :
# [[379.  17.  85.]
#  [ 28.  10.  41.]
#  [ 50.  11. 153.]]
#
# =============================================================================
# | Epoch: 17 | Train Loss: 0.330 | Train Acc: 90.96%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.812500  0.285714  0.563707
# recall      0.810811  0.126582  0.682243
# accuracy    0.751032  0.853125  0.751032
# f1-measure  0.811655  0.175439  0.617336
# | Validation Accuracy : 70.54 % - Macro F1 Score : 0.5348
# | CM on the Validation :
# [[390.  16.  75.]
#  [ 31.  10.  38.]
#  [ 59.   9. 146.]]
#
# =============================================================================
#
# | Epoch: 18 | Train Loss: 0.357 | Train Acc: 91.99%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.817021  0.300000  0.554745
# recall      0.798337  0.113924  0.710280
# accuracy    0.748626  0.856918  0.747599
# f1-measure  0.807571  0.165138  0.622951
# | Validation Accuracy : 70.41 % - Macro F1 Score : 0.5319
# | CM on the Validation :
# [[384.  14.  83.]
#  [ 31.   9.  39.]
#  [ 55.   7. 152.]]
#
# =============================================================================
#
# | Epoch: 19 | Train Loss: 0.240 | Train Acc: 92.64%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.810700  0.270270  0.565737
# recall      0.819127  0.126582  0.663551
# accuracy    0.753103  0.850467  0.751032
# f1-measure  0.814891  0.172414  0.610753
# | Validation Accuracy : 70.54 % - Macro F1 Score : 0.5327
# | CM on the Validation :
# [[394.  16.  71.]
#  [ 31.  10.  38.]
#  [ 61.  11. 142.]]
#
# =============================================================================

# %%
# 5th Step : Test the Model and save data 
classifier.test(folder='CNN_paper')
# Out:
# | Successfully save to :  ../data/results/CNN_paper/subtask_c.csv

# %% [markdown]
# ### 4) Simple RNN :
# Best Parameters :

# %%
# 2nd Step : Define Model : 
model = RNN(embedding= classifier.embedding,  
            embedding_dim = classifier.dim_vect,
            hidden_size=classifier.dim_vect, 
            output_size=classifier.nb_class,
            num_layers=2,
            output_layer = output_layer(classifier.dim_vect, classifier.nb_class,
                middle_layers = [100])) #Change this to add/remove middle layers from output

# %%
# 3rd Step : Define Optinizer : 
optimizer = optim.Adam(model.parameters(), lr=0.0001,weight_decay=0.0005)

# %%
# 4th Step : Train the Model
classifier.train( nb_epochs= 20,
                       optimizer= optimizer , 
                       model= model ,
                       batch_size= 300)
# Out:
# | Epoch: 00 | Train Loss: 1.091 | Train Acc: 36.80%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.663934  0.118881       NaN
# recall      0.673597  0.430380  0.000000
# accuracy    0.527246  0.546565  0.625874
# f1-measure  0.668731  0.186301  0.000000
# | Validation Accuracy : 46.25 % - Macro F1 Score : 0.2850
# | CM on the Validation :
# [[324. 157.   0.]
#  [ 45.  34.   0.]
#  [119.  95.   0.]]
#
# =============================================================================
# /data/anaconda/envs/mli/lib/python3.6/site-packages/ipykernel_launcher.py:199: RuntimeWarning: invalid value encountered in double_scalars
# | Epoch: 01 | Train Loss: 1.085 | Train Acc: 41.72%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.697460  0.129496  0.301587
# recall      0.627859  0.455696  0.088785
# accuracy    0.535232  0.556075  0.598993
# f1-measure  0.660832  0.201681  0.137184
# | Validation Accuracy : 46.12 % - Macro F1 Score : 0.3332
# | CM on the Validation :
# [[302. 142.  37.]
#  [ 36.  36.   7.]
#  [ 95. 100.  19.]]
#
# =============================================================================
#
# | Epoch: 02 | Train Loss: 1.081 | Train Acc: 47.76%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.756757  0.129555  0.414013
# recall      0.582121  0.405063  0.303738
# accuracy    0.564371  0.589984  0.610032
# f1-measure  0.658049  0.196319  0.350404
# | Validation Accuracy : 48.71 % - Macro F1 Score : 0.4016
# | CM on the Validation :
# [[280. 125.  76.]
#  [ 31.  32.  16.]
#  [ 59.  90.  65.]]
#
# =============================================================================
#
# | Epoch: 03 | Train Loss: 1.028 | Train Acc: 50.80%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.761671  0.137615  0.416107
# recall      0.644491  0.379747  0.289720
# accuracy    0.600000  0.629108  0.627145
# f1-measure  0.698198  0.202020  0.341598
# | Validation Accuracy : 51.94 % - Macro F1 Score : 0.4139
# | CM on the Validation :
# [[310. 103.  68.]
#  [ 30.  30.  19.]
#  [ 67.  85.  62.]]
#
# =============================================================================
#
# | Epoch: 04 | Train Loss: 0.966 | Train Acc: 51.88%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.818421  0.145038  0.414449
# recall      0.646570  0.240506  0.509346
# accuracy    0.647493  0.718494  0.628940
# f1-measure  0.722416  0.180952  0.457023
# | Validation Accuracy : 56.72 % - Macro F1 Score : 0.4535
# | CM on the Validation :
# [[311.  52. 118.]
#  [ 24.  19.  36.]
#  [ 45.  60. 109.]]
#
# =============================================================================
#
# | Epoch: 05 | Train Loss: 0.999 | Train Acc: 52.39%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.804054  0.151515  0.493506
# recall      0.742204  0.189873  0.532710
# accuracy    0.697274  0.766562  0.691323
# f1-measure  0.771892  0.168539  0.512360
# | Validation Accuracy : 62.79 % - Macro F1 Score : 0.4843
# | CM on the Validation :
# [[357.  45.  79.]
#  [ 26.  15.  38.]
#  [ 61.  39. 114.]]
#
# =============================================================================
#
# | Epoch: 06 | Train Loss: 0.932 | Train Acc: 56.53%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.825243  0.150000  0.484733
# recall      0.706861  0.189873  0.593458
# accuracy    0.693525  0.763867  0.684659
# f1-measure  0.761478  0.167598  0.533613
# | Validation Accuracy : 62.27 % - Macro F1 Score : 0.4876
# | CM on the Validation :
# [[340.  47.  94.]
#  [ 23.  15.  41.]
#  [ 49.  38. 127.]]
#
# =============================================================================
#
# | Epoch: 07 | Train Loss: 0.884 | Train Acc: 59.01%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.844737  0.123188  0.492188
# recall      0.667360  0.215190  0.588785
# accuracy    0.679356  0.717156  0.680352
# f1-measure  0.745645  0.156682  0.536170
# | Validation Accuracy : 59.95 % - Macro F1 Score : 0.4795
# | CM on the Validation :
# [[321.  70.  90.]
#  [ 22.  17.  40.]
#  [ 37.  51. 126.]]
#
# =============================================================================
#
# | Epoch: 08 | Train Loss: 0.951 | Train Acc: 60.47%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.815217  0.144144  0.566502
# recall      0.779626  0.202532  0.537383
# accuracy    0.725968  0.762048  0.730159
# f1-measure  0.797024  0.168421  0.551559
# | Validation Accuracy : 65.37 % - Macro F1 Score : 0.5057
# | CM on the Validation :
# [[375.  52.  54.]
#  [ 29.  16.  34.]
#  [ 56.  43. 115.]]
#
# =============================================================================
#
# | Epoch: 09 | Train Loss: 0.793 | Train Acc: 63.52%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.843284  0.155340  0.494424
# recall      0.704782  0.202532  0.621495
# accuracy    0.704185  0.764890  0.692199
# f1-measure  0.767837  0.175824  0.550725
# | Validation Accuracy : 63.05 % - Macro F1 Score : 0.4981
# | CM on the Validation :
# [[339.  48.  94.]
#  [ 21.  16.  42.]
#  [ 42.  39. 133.]]
#
# =============================================================================
#
# | Epoch: 10 | Train Loss: 0.894 | Train Acc: 65.76%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.848866  0.121212  0.528302
# recall      0.700624  0.253165  0.523364
# accuracy    0.696880  0.696880  0.698957
# f1-measure  0.767654  0.163934  0.525822
# | Validation Accuracy : 60.59 % - Macro F1 Score : 0.4858
# | CM on the Validation :
# [[337.  82.  62.]
#  [ 21.  20.  38.]
#  [ 39.  63. 112.]]
#
# =============================================================================
#
# | Epoch: 11 | Train Loss: 0.711 | Train Acc: 68.76%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.842482  0.145631  0.519841
# recall      0.733888  0.189873  0.612150
# accuracy    0.720058  0.766513  0.709815
# f1-measure  0.784444  0.164835  0.562232
# | Validation Accuracy : 64.47 % - Macro F1 Score : 0.5038
# | CM on the Validation :
# [[353.  48.  80.]
#  [ 23.  15.  41.]
#  [ 43.  40. 131.]]
#
# =============================================================================
#
# | Epoch: 12 | Train Loss: 0.692 | Train Acc: 70.98%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.867978  0.119403  0.468310
# recall      0.642412  0.202532  0.621495
# accuracy    0.676514  0.716745  0.663768
# f1-measure  0.738351  0.150235  0.534137
# | Validation Accuracy : 59.17 % - Macro F1 Score : 0.4742
# | CM on the Validation :
# [[309.  67. 105.]
#  [ 17.  16.  46.]
#  [ 30.  51. 133.]]
#
# =============================================================================
#
# | Epoch: 13 | Train Loss: 0.661 | Train Acc: 73.18%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.820628  0.136000  0.556650
# recall      0.760915  0.215190  0.528037
# accuracy    0.717800  0.744745  0.721980
# f1-measure  0.789644  0.166667  0.541966
# | Validation Accuracy : 64.08 % - Macro F1 Score : 0.4994
# | CM on the Validation :
# [[366.  59.  56.]
#  [ 28.  17.  34.]
#  [ 52.  49. 113.]]
#
# =============================================================================
#
# | Epoch: 14 | Train Loss: 0.517 | Train Acc: 76.53%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.880734  0.113095  0.465950
# recall      0.598753  0.240506  0.607477
# accuracy    0.653214  0.676471  0.652239
# f1-measure  0.712871  0.153846  0.527383
# | Validation Accuracy : 56.46 % - Macro F1 Score : 0.4647
# | CM on the Validation :
# [[288.  89. 104.]
#  [ 15.  19.  45.]
#  [ 24.  60. 130.]]
#
# =============================================================================
#
# | Epoch: 15 | Train Loss: 0.640 | Train Acc: 77.49%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.857923  0.125749  0.497925
# recall      0.652807  0.265823  0.560748
# accuracy    0.675074  0.690440  0.679104
# f1-measure  0.741440  0.170732  0.527473
# | Validation Accuracy : 58.79 % - Macro F1 Score : 0.4799
# | CM on the Validation :
# [[314.  84.  83.]
#  [ 20.  21.  38.]
#  [ 32.  62. 120.]]
#
# =============================================================================
#
# | Epoch: 16 | Train Loss: 0.600 | Train Acc: 79.22%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.845758  0.134146  0.515837
# recall      0.683992  0.278481  0.532710
# accuracy    0.686854  0.700301  0.691964
# f1-measure  0.756322  0.181070  0.524138
# | Validation Accuracy : 60.08 % - Macro F1 Score : 0.4872
# | CM on the Validation :
# [[329.  79.  73.]
#  [ 23.  22.  34.]
#  [ 37.  63. 114.]]
#
# =============================================================================
#
# | Epoch: 17 | Train Loss: 0.428 | Train Acc: 82.31%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.857909  0.127389  0.504098
# recall      0.665281  0.253165  0.574766
# accuracy    0.683900  0.702580  0.685926
# f1-measure  0.749415  0.169492  0.537118
# | Validation Accuracy : 59.82 % - Macro F1 Score : 0.4853
# | CM on the Validation :
# [[320.  79.  82.]
#  [ 20.  20.  39.]
#  [ 33.  58. 123.]]
#
# =============================================================================
# | Epoch: 18 | Train Loss: 0.504 | Train Acc: 83.85%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.853093  0.123810  0.483986
# recall      0.688150  0.164557  0.635514
# accuracy    0.698690  0.752351  0.682788
# f1-measure  0.761795  0.141304  0.549495
# | Validation Accuracy : 62.02 % - Macro F1 Score : 0.4842
# | CM on the Validation :
# [[331.  49. 101.]
#  [ 22.  13.  44.]
#  [ 35.  43. 136.]]
#
# =============================================================================
#
# | Epoch: 19 | Train Loss: 0.317 | Train Acc: 85.39%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.867606  0.132812  0.477663
# recall      0.640333  0.215190  0.649533
# accuracy    0.678363  0.728414  0.671491
# f1-measure  0.736842  0.164251  0.550495
# | Validation Accuracy : 59.95 % - Macro F1 Score : 0.4839
# | CM on the Validation :
# [[308.  65. 108.]
#  [ 18.  17.  44.]
#  [ 29.  46. 139.]]
#
# =============================================================================

# %%
# 5th Step : Test the Model and save data 
classifier.test(folder='RNN')
# Out:
# | Successfully save to :  ../data/results/RNN/subtask_c.csv

# %% [markdown]
# ### 5) LSTM :
# Best Parameters :

# %%
# 2nd Step : Define Model : 
model = LSTM(embedding= classifier.embedding,  
            embedding_dim = classifier.dim_vect,
            hidden_size=classifier.dim_vect, 
            output_size=classifier.nb_class,
            num_layers=1,
            output_layer = output_layer(classifier.dim_vect, classifier.nb_class,
                middle_layers = [200,100])) #Change this to add/remove middle layers from output

# %%
# 3rd Step : Define Optinizer : 
optimizer = optim.Adam(model.parameters(), lr=0.001,weight_decay=0.0001)

# %%
# 4th Step : Train the Model
classifier.train( nb_epochs= 10,
                       optimizer= optimizer , 
                       model= model ,
                       batch_size= 300)
# Out:
# | Epoch: 00 | Train Loss: 1.006 | Train Acc: 41.32%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.889590  0.166667  0.424719
# recall      0.586279  0.025316  0.883178
# accuracy    0.669024  0.844643  0.627321
# f1-measure  0.706767  0.043956  0.573596
# | Validation Accuracy : 61.11 % - Macro F1 Score : 0.4414
# | CM on the Validation :
# [[282.   7. 192.]
#  [ 13.   2.  64.]
#  [ 22.   3. 189.]]
#
# =============================================================================
#
# | Epoch: 01 | Train Loss: 0.997 | Train Acc: 52.53%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.869565  0.145078  0.552632
# recall      0.706861  0.354430  0.490654
# accuracy    0.711278  0.686502  0.709145
# f1-measure  0.779817  0.205882  0.519802
# | Validation Accuracy : 61.11 % - Macro F1 Score : 0.5018
# | CM on the Validation :
# [[340.  86.  55.]
#  [ 21.  28.  30.]
#  [ 30.  79. 105.]]
#
# =============================================================================
#
# | Epoch: 02 | Train Loss: 0.865 | Train Acc: 58.83%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.907975  0.165468  0.491909
# recall      0.615385  0.291139  0.710280
# accuracy    0.686589  0.732504  0.682609
# f1-measure  0.733581  0.211009  0.581262
# | Validation Accuracy : 60.85 % - Macro F1 Score : 0.5086
# | CM on the Validation :
# [[296.  71. 114.]
#  [ 13.  23.  43.]
#  [ 17.  45. 152.]]
#
# =============================================================================
#
# | Epoch: 03 | Train Loss: 0.889 | Train Acc: 62.27%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.872449  0.154589  0.554286
# recall      0.711019  0.405063  0.453271
# accuracy    0.713636  0.679654  0.707207
# f1-measure  0.783505  0.223776  0.498715
# | Validation Accuracy : 60.85 % - Macro F1 Score : 0.5020
# | CM on the Validation :
# [[342.  88.  51.]
#  [ 20.  32.  27.]
#  [ 30.  87.  97.]]
#
# =============================================================================
#
# | Epoch: 04 | Train Loss: 0.663 | Train Acc: 67.48%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.897436  0.131783  0.504505
# recall      0.582121  0.215190  0.785047
# accuracy    0.666189  0.727700  0.687870
# f1-measure  0.706179  0.163462  0.614260
# | Validation Accuracy : 60.08 % - Macro F1 Score : 0.4946
# | CM on the Validation :
# [[280.  82. 119.]
#  [ 16.  17.  46.]
#  [ 16.  30. 168.]]
#
# =============================================================================
#
# | Epoch: 05 | Train Loss: 0.711 | Train Acc: 72.05%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.866261  0.109524  0.523404
# recall      0.592516  0.291139  0.574766
# accuracy    0.642325  0.639466  0.679811
# f1-measure  0.703704  0.159170  0.547884
# | Validation Accuracy : 55.68 % - Macro F1 Score : 0.4703
# | CM on the Validation :
# [[285. 122.  74.]
#  [ 18.  23.  38.]
#  [ 26.  65. 123.]]
#
# =============================================================================
#
# | Epoch: 06 | Train Loss: 0.433 | Train Acc: 80.05%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.880407  0.146667  0.526144
# recall      0.719335  0.139241  0.752336
# accuracy    0.740000  0.796923  0.723464
# f1-measure  0.791762  0.142857  0.619231
# | Validation Accuracy : 66.93 % - Macro F1 Score : 0.5179
# | CM on the Validation :
# [[346.  35. 100.]
#  [ 23.  11.  45.]
#  [ 24.  29. 161.]]
#
# =============================================================================
#
# | Epoch: 07 | Train Loss: 0.401 | Train Acc: 84.80%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.851064  0.127660  0.540856
# recall      0.748441  0.151899  0.649533
# accuracy    0.735252  0.774242  0.725852
# f1-measure  0.796460  0.138728  0.590234
# | Validation Accuracy : 66.02 % - Macro F1 Score : 0.5085
# | CM on the Validation :
# [[360.  41.  80.]
#  [ 29.  12.  38.]
#  [ 34.  41. 139.]]
#
# =============================================================================
#
# | Epoch: 08 | Train Loss: 0.323 | Train Acc: 88.30%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.828054  0.106667  0.544747
# recall      0.760915  0.101266  0.654206
# accuracy    0.729078  0.788344  0.729078
# f1-measure  0.793066  0.103896  0.594480
# | Validation Accuracy : 66.41 % - Macro F1 Score : 0.4971
# | CM on the Validation :
# [[366.  34.  81.]
#  [ 35.   8.  36.]
#  [ 41.  33. 140.]]
#
# =============================================================================
#
# | Epoch: 09 | Train Loss: 0.212 | Train Acc: 89.18%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.853301  0.113636  0.530686
# recall      0.725572  0.126582  0.686916
# accuracy    0.724928  0.774885  0.719772
# f1-measure  0.784270  0.119760  0.598778
# | Validation Accuracy : 65.37 % - Macro F1 Score : 0.5009
# | CM on the Validation :
# [[349.  42.  90.]
#  [ 29.  10.  40.]
#  [ 31.  36. 147.]]
#
# =============================================================================

# %%
# 5th Step : Test the Model and save data 
classifier.test(folder='LSTM')

# %% [markdown]
# ### 6) GRU :
# Best Parameters :

# %%
# 2nd Step : Define Model : 
model = GRU(embedding= classifier.embedding,  
            embedding_dim = classifier.dim_vect,
            hidden_size=classifier.dim_vect, 
            output_size=classifier.nb_class,
            num_layers=1,
            output_layer = output_layer(classifier.dim_vect, classifier.nb_class,
                middle_layers = [200,100])) #Change this to add/remove middle layers from output

# %%
# 3rd Step : Define Optinizer : 
optimizer = optim.Adam(model.parameters(), lr=0.001,weight_decay=0.005)

# %%
# 4th Step : Train the Model
classifier.train( nb_epochs= 20,
                       optimizer= optimizer , 
                       model= model ,
                       batch_size= 100)
# Out:
# | Epoch: 00 | Train Loss: 0.996 | Train Acc: 40.81%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.825472       NaN  0.482857
# recall      0.727651  0.000000  0.789720
# accuracy    0.716851  0.867893  0.696644
# f1-measure  0.773481  0.000000  0.599291
# | Validation Accuracy : 67.05 % - Macro F1 Score : 0.4576
# | CM on the Validation :
# [[350.   0. 131.]
#  [ 29.   0.  50.]
#  [ 45.   0. 169.]]
#
# =============================================================================
# /data/anaconda/envs/mli/lib/python3.6/site-packages/ipykernel_launcher.py:199: RuntimeWarning: invalid value encountered in double_scalars
# | Epoch: 01 | Train Loss: 0.924 | Train Acc: 51.25%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.925373  0.170732  0.430108
# recall      0.515593  0.088608  0.934579
# accuracy    0.642655  0.811052  0.619891
# f1-measure  0.662216  0.116667  0.589102
# | Validation Accuracy : 58.79 % - Macro F1 Score : 0.4560
# | CM on the Validation :
# [[248.  29. 204.]
#  [ 11.   7.  61.]
#  [  9.   5. 200.]]
#
# =============================================================================
#
# | Epoch: 02 | Train Loss: 0.923 | Train Acc: 53.16%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.911429  0.162162  0.520000
# recall      0.663202  0.151899  0.850467
# accuracy    0.726629  0.799065  0.719495
# f1-measure  0.767750  0.156863  0.645390
# | Validation Accuracy : 66.28 % - Macro F1 Score : 0.5233
# | CM on the Validation :
# [[319.  45. 117.]
#  [ 16.  12.  51.]
#  [ 15.  17. 182.]]
#
# =============================================================================
#
# | Epoch: 03 | Train Loss: 0.921 | Train Acc: 54.51%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.890411  0.126050  0.562069
# recall      0.675676  0.189873  0.761682
# accuracy    0.719599  0.749627  0.738620
# f1-measure  0.768322  0.151515  0.646825
# | Validation Accuracy : 64.99 % - Macro F1 Score : 0.5222
# | CM on the Validation :
# [[325.  73.  83.]
#  [ 20.  15.  44.]
#  [ 20.  31. 163.]]
#
# =============================================================================
#
# | Epoch: 04 | Train Loss: 0.895 | Train Acc: 56.48%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.894022  0.136986  0.528529
# recall      0.683992  0.126582  0.822430
# accuracy    0.729462  0.795981  0.725352
# f1-measure  0.775029  0.131579  0.643510
# | Validation Accuracy : 66.54 % - Macro F1 Score : 0.5167
# | CM on the Validation :
# [[329.  46. 106.]
#  [ 18.  10.  51.]
#  [ 21.  17. 176.]]
#
# =============================================================================
#
# | Epoch: 05 | Train Loss: 0.868 | Train Acc: 60.13%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.863309  0.140845  0.562791
# recall      0.748441  0.253165  0.565421
# accuracy    0.737850  0.734604  0.728198
# f1-measure  0.801782  0.180995  0.564103
# | Validation Accuracy : 64.73 % - Macro F1 Score : 0.5156
# | CM on the Validation :
# [[360.  65.  56.]
#  [ 21.  20.  38.]
#  [ 36.  57. 121.]]
#
# =============================================================================
#
# | Epoch: 06 | Train Loss: 0.834 | Train Acc: 61.05%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.910217  0.140351  0.507418
# recall      0.611227  0.202532  0.799065
# accuracy    0.690100  0.749221  0.697101
# f1-measure  0.731343  0.165803  0.620690
# | Validation Accuracy : 62.14 % - Macro F1 Score : 0.5059
# | CM on the Validation :
# [[294.  69. 118.]
#  [ 15.  16.  48.]
#  [ 14.  29. 171.]]
#
# =============================================================================
#
# | Epoch: 07 | Train Loss: 0.746 | Train Acc: 62.87%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.902367  0.133690  0.518072
# recall      0.634096  0.316456  0.602804
# accuracy    0.687126  0.680000  0.691265
# f1-measure  0.744811  0.187970  0.557235
# | Validation Accuracy : 59.30 % - Macro F1 Score : 0.4967
# | CM on the Validation :
# [[305.  94.  82.]
#  [ 16.  25.  38.]
#  [ 17.  68. 129.]]
#
# =============================================================================
#
# | Epoch: 08 | Train Loss: 0.790 | Train Acc: 65.83%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.870968  0.134021  0.528846
# recall      0.673597  0.329114  0.514019
# accuracy    0.691729  0.675477  0.694864
# f1-measure  0.759672  0.190476  0.521327
# | Validation Accuracy : 59.43 % - Macro F1 Score : 0.4905
# | CM on the Validation :
# [[324.  93.  64.]
#  [ 19.  26.  34.]
#  [ 29.  75. 110.]]
#
# =============================================================================
#
# | Epoch: 09 | Train Loss: 0.667 | Train Acc: 67.91%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.882682  0.118012  0.498039
# recall      0.656965  0.240506  0.593458
# accuracy    0.690583  0.695783  0.682422
# f1-measure  0.753278  0.158333  0.541578
# | Validation Accuracy : 59.69 % - Macro F1 Score : 0.4844
# | CM on the Validation :
# [[316.  80.  85.]
#  [ 17.  19.  43.]
#  [ 25.  62. 127.]]
#
# =============================================================================
#
# | Epoch: 10 | Train Loss: 0.664 | Train Acc: 69.90%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.870886  0.144828  0.542735
# recall      0.715177  0.265823  0.593458
# accuracy    0.723529  0.729970  0.717201
# f1-measure  0.785388  0.187500  0.566964
# | Validation Accuracy : 63.57 % - Macro F1 Score : 0.5133
# | CM on the Validation :
# [[344.  67.  70.]
#  [ 21.  21.  37.]
#  [ 30.  57. 127.]]
#
# =============================================================================
#
# | Epoch: 11 | Train Loss: 0.691 | Train Acc: 72.16%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.860892  0.141176  0.524664
# recall      0.681913  0.303797  0.546729
# accuracy    0.694815  0.700000  0.697917
# f1-measure  0.761021  0.192771  0.535469
# | Validation Accuracy : 60.59 % - Macro F1 Score : 0.4964
# | CM on the Validation :
# [[328.  82.  71.]
#  [ 20.  24.  35.]
#  [ 33.  64. 117.]]
#
# =============================================================================
#
# | Epoch: 12 | Train Loss: 0.530 | Train Acc: 75.74%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.858726  0.118721  0.525773
# recall      0.644491  0.329114  0.476636
# accuracy    0.663636  0.640351  0.682243
# f1-measure  0.736342  0.174497  0.500000
# | Validation Accuracy : 56.59 % - Macro F1 Score : 0.4703
# | CM on the Validation :
# [[310. 111.  60.]
#  [ 21.  26.  32.]
#  [ 30.  82. 102.]]
#
# =============================================================================
#
# | Epoch: 13 | Train Loss: 0.606 | Train Acc: 78.73%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.872629  0.125000  0.509881
# recall      0.669439  0.240506  0.602804
# accuracy    0.695266  0.708899  0.692194
# f1-measure  0.757647  0.164502  0.552463
# | Validation Accuracy : 60.72 % - Macro F1 Score : 0.4915
# | CM on the Validation :
# [[322.  75.  84.]
#  [ 20.  19.  40.]
#  [ 27.  58. 129.]]
#
# =============================================================================
#
# | Epoch: 14 | Train Loss: 0.422 | Train Acc: 81.53%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.862694  0.096491  0.510949
# recall      0.692308  0.139241  0.654206
# accuracy    0.706569  0.738931  0.699422
# f1-measure  0.768166  0.113990  0.573770
# | Validation Accuracy : 62.53 % - Macro F1 Score : 0.4853
# | CM on the Validation :
# [[333.  60.  88.]
#  [ 22.  11.  46.]
#  [ 31.  43. 140.]]
#
# =============================================================================
#
# | Epoch: 15 | Train Loss: 0.515 | Train Acc: 83.55%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.860294  0.127119  0.520161
# recall      0.729730  0.189873  0.602804
# accuracy    0.725806  0.747734  0.708155
# f1-measure  0.789651  0.152284  0.558442
# | Validation Accuracy : 63.95 % - Macro F1 Score : 0.5001
# | CM on the Validation :
# [[351.  51.  79.]
#  [ 24.  15.  40.]
#  [ 33.  52. 129.]]
#
# =============================================================================
#
# | Epoch: 16 | Train Loss: 0.352 | Train Acc: 84.66%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.882006  0.139706  0.474916
# recall      0.621622  0.240506  0.663551
# accuracy    0.674487  0.722135  0.667634
# f1-measure  0.729268  0.176744  0.553606
# | Validation Accuracy : 59.43 % - Macro F1 Score : 0.4865
# | CM on the Validation :
# [[299.  68. 114.]
#  [ 17.  19.  43.]
#  [ 23.  49. 142.]]
#
# =============================================================================
#
# | Epoch: 17 | Train Loss: 0.448 | Train Acc: 85.52%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.843902  0.105691  0.526971
# recall      0.719335  0.164557  0.593458
# accuracy    0.709489  0.734139  0.707424
# f1-measure  0.776655  0.128713  0.558242
# | Validation Accuracy : 62.79 % - Macro F1 Score : 0.4879
# | CM on the Validation :
# [[346.  58.  77.]
#  [ 29.  13.  37.]
#  [ 35.  52. 127.]]
#
# =============================================================================
# | Epoch: 18 | Train Loss: 0.379 | Train Acc: 85.52%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.865079  0.117647  0.500000
# recall      0.679834  0.151899  0.686916
# accuracy    0.703329  0.755832  0.694286
# f1-measure  0.761350  0.132597  0.578740
# | Validation Accuracy : 62.79 % - Macro F1 Score : 0.4909
# | CM on the Validation :
# [[327.  52. 102.]
#  [ 22.  12.  45.]
#  [ 29.  38. 147.]]
#
# =============================================================================
#
# | Epoch: 19 | Train Loss: 0.308 | Train Acc: 87.58%
# | Stats on the Validation :
#                  IND       OTH       GRP
# precision   0.879310  0.137615  0.482650
# recall      0.636175  0.189873  0.714953
# accuracy    0.685962  0.750000  0.678112
# f1-measure  0.738239  0.159574  0.576271
# | Validation Accuracy : 61.24 % - Macro F1 Score : 0.4914
# | CM on the Validation :
# [[306.  57. 118.]
#  [ 18.  15.  46.]
#  [ 24.  37. 153.]]
#
# =============================================================================

# %%
# 5th Step : Test the Model and save data 
classifier.test(folder='GRU')
# Out:
# | Successfully save to :  ../data/results/GRU/subtask_c_1.csv

# %% [markdown]
# ### :O

# %%
classifierA = OffensiveClassifier(subtask='subtask_a', dim_vect=200 , pValid = 0.2)
classifierB = OffensiveClassifier(subtask='subtask_b', dim_vect=200 , pValid = 0.2)
classifierC = OffensiveClassifier(subtask='subtask_c', dim_vect=200 , pValid = 0.2)

classifiers = [classifierA , classifierB , classifierC]
# Out:
# ---- Loading the processed GloVe files : Done
# ---- Creating the Pytorch Embedding Layer  : Done
# -- Data Handling :
# ---- Load the Clean Adapted Dataset : Done
# ---- Augmenting the Data :
# Before Augmentation :  {'NOT': 7072, 'OFF': 3520}
# After Augmentation :  {'NOT': 7072, 'OFF': 7072}
# ---- Loading the processed GloVe files : Done
# ---- Creating the Pytorch Embedding Layer  : Done
# -- Data Handling :
# ---- Load the Clean Adapted Dataset : Done
# ---- Augmenting the Data :
# Before Augmentation :  {'UNT': 420, 'TIN': 3101}
# After Augmentation :  {'UNT': 3101, 'TIN': 3101}
# ---- Loading the processed GloVe files : Done
# ---- Creating the Pytorch Embedding Layer  : Done
# -- Data Handling :
# ---- Load the Clean Adapted Dataset : Done
# ---- Augmenting the Data :
# Before Augmentation :  {'IND': 1926, 'OTH': 316, 'GRP': 860}
# After Augmentation :  {'IND': 1926, 'OTH': 1926, 'GRP': 1926}

# %%
# 1st step : Define Classifier for specific task
# 3rd Step : Define Optinizer : 
optimizer = optim.Adam(model.parameters(), lr=0.0001,weight_decay=0.005)

lrs=[1e-04,1e-03,1e-02]
weight_decays=[0,0.001,0.01]

model_RNN = RNN(embedding= classifier.embedding, 
            embedding_dim = classifier.dim_vect,
            hidden_size=classifier.dim_vect, 
            output_size=classifier.nb_class,
            num_layers=1,
            output_layer = output_layer(classifier.dim_vect, classifier.nb_class,
                middle_layers = [])) 

model_LSTM = LSTM(embedding= classifier.embedding, 
            embedding_dim = classifier.dim_vect,
            hidden_size=classifier.dim_vect, 
            output_size=classifier.nb_class,
            num_layers=1,
            output_layer = output_layer(classifier.dim_vect, classifier.nb_class,
                middle_layers = [])) 

model_GRU = GRU(embedding= classifier.embedding, 
            embedding_dim = classifier.dim_vect,
            hidden_size=classifier.dim_vect, 
            output_size=classifier.nb_class,
            num_layers=1,
            output_layer = output_layer(classifier.dim_vect, classifier.nb_class,
                middle_layers = [])) 

models = [model_RNN , model_LSTM , model_GRU]

middle_layers = [
    [],
    [200],
    [200,100],
]

#num_layers = [1]

hidden_sizes_extra = [-50,0,50]

results=[]
counter =0
for classifier in classifiers:
    for model in models:
        model.output_size = classifier.nb_class
        for hidden_size in hidden_sizes_extra:
            model.hidden_size = 200 + hidden_size
            for middle_layer in middle_layers:
                for lr in lrs:
                    for weight_decay in weight_decays:
                        optimizer = optim.Adam(model.parameters(), lr=lr,weight_decay=weight_decay)
                        model.output_layer = output_layer(200 + hidden_size, classifier.nb_class,
                                                          middle_layers = middle_layer) 
                        score = classifier.train( nb_epochs= 10,
                               optimizer= optimizer , 
                               model= model ,
                               batch_size= 100)

                        if isinstance(model,RNN):
                            model_name="RNN"
                        elif isinstance(model,LSTM):
                            model_name="LSTM"
                        else:
                            model_name="GRU"
                        res={
                            "model": model_name,
                            "score": score,
                            "task": classifier.subtask,
                            "hidden_size": hidden_size,
                            "num_layer": num_layer,
                            "lr": lr,
                            "weight_decay": weight_decay,
                            "middle_layers": middle_layer
                        }
                        counter+=1
                        print(counter, res)
                        results.append(res)
# Out:
# | Epoch: 00 | Train Loss: 0.664 | Train Acc: 56.20%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.746373  0.478919
# recall      0.727376  0.503409
# accuracy    0.652946  0.652946
# f1-measure  0.736752  0.490859
# | Validation Accuracy : 65.29 % - Macro F1 Score : 0.6138
# | CM on the Validation :
# [[1286.  482.]
#  [ 437.  443.]]
#
# =============================================================================
#
# 1 {'model': 'RNN', 'score': 0.6138051864271482, 'task': 'subtask_a', 'hidden_size': -50, 'num_layer': 2, 'lr': 0.0001, 'weight_decay': 0, 'middle_layers': []}
# | Epoch: 00 | Train Loss: 0.661 | Train Acc: 62.18%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.778378  0.519837
# recall      0.733032  0.580682
# accuracy    0.682402  0.682402
# f1-measure  0.755025  0.548578
# | Validation Accuracy : 68.24 % - Macro F1 Score : 0.6518
# | CM on the Validation :
# [[1296.  472.]
#  [ 369.  511.]]
#
# =============================================================================
#
# 2 {'model': 'RNN', 'score': 0.6518011613778616, 'task': 'subtask_a', 'hidden_size': -50, 'num_layer': 2, 'lr': 0.0001, 'weight_decay': 0.001, 'middle_layers': []}
# | Epoch: 00 | Train Loss: 0.681 | Train Acc: 69.50%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.834918  0.541667
# recall      0.695136  0.723864
# accuracy    0.704683  0.704683
# f1-measure  0.758642  0.619650
# | Validation Accuracy : 70.47 % - Macro F1 Score : 0.6891
# | CM on the Validation :
# [[1229.  539.]
#  [ 243.  637.]]
#
# =============================================================================
#
# 3 {'model': 'RNN', 'score': 0.6891458903780564, 'task': 'subtask_a', 'hidden_size': -50, 'num_layer': 2, 'lr': 0.0001, 'weight_decay': 0.01, 'middle_layers': []}
# | Epoch: 00 | Train Loss: 0.497 | Train Acc: 71.31%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.887411  0.495395
# recall      0.566176  0.855682
# accuracy    0.662387  0.662387
# f1-measure  0.691298  0.627500
# | Validation Accuracy : 66.24 % - Macro F1 Score : 0.6594
# | CM on the Validation :
# [[1001.  767.]
#  [ 127.  753.]]
#
# =============================================================================
#
# 4 {'model': 'RNN', 'score': 0.6593991712707182, 'task': 'subtask_a', 'hidden_size': -50, 'num_layer': 2, 'lr': 0.001, 'weight_decay': 0, 'middle_layers': []}
# | Epoch: 00 | Train Loss: 0.524 | Train Acc: 75.27%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.851877  0.570069
# recall      0.718891  0.748864
# accuracy    0.728852  0.728852
# f1-measure  0.779755  0.647348
# | Validation Accuracy : 72.89 % - Macro F1 Score : 0.7136
# | CM on the Validation :
# [[1271.  497.]
#  [ 221.  659.]]
#
# =============================================================================
#
# 5 {'model': 'RNN', 'score': 0.7135511709474851, 'task': 'subtask_a', 'hidden_size': -50, 'num_layer': 2, 'lr': 0.001, 'weight_decay': 0.001, 'middle_layers': []}
# | Epoch: 00 | Train Loss: 0.478 | Train Acc: 77.48%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.841749  0.608398
# recall      0.773190  0.707955
# accuracy    0.751511  0.751511
# f1-measure  0.806014  0.654412
# | Validation Accuracy : 75.15 % - Macro F1 Score : 0.7302
# | CM on the Validation :
# [[1367.  401.]
#  [ 257.  623.]]
#
# =============================================================================
#
# 6 {'model': 'RNN', 'score': 0.7302129578246392, 'task': 'subtask_a', 'hidden_size': -50, 'num_layer': 2, 'lr': 0.001, 'weight_decay': 0.01, 'middle_layers': []}
# | Epoch: 00 | Train Loss: 0.648 | Train Acc: 60.22%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.746041  0.460239
# recall      0.692873  0.526136
# accuracy    0.637462  0.637462
# f1-measure  0.718475  0.490986
# | Validation Accuracy : 63.75 % - Macro F1 Score : 0.6047
# | CM on the Validation :
# [[1225.  543.]
#  [ 417.  463.]]
#
# =============================================================================
#
# 7 {'model': 'RNN', 'score': 0.6047306437618756, 'task': 'subtask_a', 'hidden_size': -50, 'num_layer': 2, 'lr': 0.01, 'weight_decay': 0, 'middle_layers': []}
# | Epoch: 00 | Train Loss: 0.560 | Train Acc: 61.52%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.793534  0.465423
# recall      0.610860  0.680682
# accuracy    0.634063  0.634063
# f1-measure  0.690316  0.552838
# | Validation Accuracy : 63.41 % - Macro F1 Score : 0.6216
# | CM on the Validation :
# [[1080.  688.]
#  [ 281.  599.]]
#
# =============================================================================
#
# 8 {'model': 'RNN', 'score': 0.6215772099668124, 'task': 'subtask_a', 'hidden_size': -50, 'num_layer': 2, 'lr': 0.01, 'weight_decay': 0.001, 'middle_layers': []}
# | Epoch: 00 | Train Loss: 0.662 | Train Acc: 67.76%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.725604  0.539792
# recall      0.849548  0.354545
# accuracy    0.685045  0.685045
# f1-measure  0.782699  0.427984
# | Validation Accuracy : 68.50 % - Macro F1 Score : 0.6053
# | CM on the Validation :
# [[1502.  266.]
#  [ 568.  312.]]
#
# =============================================================================
#
# 9 {'model': 'RNN', 'score': 0.6053414308292427, 'task': 'subtask_a', 'hidden_size': -50, 'num_layer': 2, 'lr': 0.01, 'weight_decay': 0.01, 'middle_layers': []}
# | Epoch: 00 | Train Loss: 0.661 | Train Acc: 63.85%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.797316  0.481331
# recall      0.638575  0.673864
# accuracy    0.650302  0.650302
# f1-measure  0.709171  0.561553
# | Validation Accuracy : 65.03 % - Macro F1 Score : 0.6354
# | CM on the Validation :
# [[1129.  639.]
#  [ 287.  593.]]
#
# =============================================================================
#
# 10 {'model': 'RNN', 'score': 0.6353619422871934, 'task': 'subtask_a', 'hidden_size': -50, 'num_layer': 2, 'lr': 0.0001, 'weight_decay': 0, 'middle_layers': [200]}
# | Epoch: 00 | Train Loss: 0.611 | Train Acc: 71.45%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.842039  0.593957
# recall      0.756787  0.714773
# accuracy    0.742825  0.742825
# f1-measure  0.797140  0.648788
# | Validation Accuracy : 74.28 % - Macro F1 Score : 0.7230
# | CM on the Validation :
# [[1338.  430.]
#  [ 251.  629.]]
#
# =============================================================================
#
# 11 {'model': 'RNN', 'score': 0.7229641694561701, 'task': 'subtask_a', 'hidden_size': -50, 'num_layer': 2, 'lr': 0.0001, 'weight_decay': 0.001, 'middle_layers': [200]}
# | Epoch: 00 | Train Loss: 0.516 | Train Acc: 74.27%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.845018  0.614481
# recall      0.777149  0.713636
# accuracy    0.756042  0.756042
# f1-measure  0.809664  0.660358
# | Validation Accuracy : 75.60 % - Macro F1 Score : 0.7350
# | CM on the Validation :
# [[1374.  394.]
#  [ 252.  628.]]
#
# =============================================================================
#
# 12 {'model': 'RNN', 'score': 0.7350108157712596, 'task': 'subtask_a', 'hidden_size': -50, 'num_layer': 2, 'lr': 0.0001, 'weight_decay': 0.01, 'middle_layers': [200]}
# | Epoch: 00 | Train Loss: 0.546 | Train Acc: 69.46%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.831347  0.615464
# recall      0.789027  0.678409
# accuracy    0.752266  0.752266
# f1-measure  0.809634  0.645405
# | Validation Accuracy : 75.23 % - Macro F1 Score : 0.7275
# | CM on the Validation :
# [[1395.  373.]
#  [ 283.  597.]]
#
# =============================================================================
#
# 13 {'model': 'RNN', 'score': 0.727519882041066, 'task': 'subtask_a', 'hidden_size': -50, 'num_layer': 2, 'lr': 0.001, 'weight_decay': 0, 'middle_layers': [200]}
# | Epoch: 00 | Train Loss: 0.592 | Train Acc: 74.98%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.860178  0.568545
# recall      0.709842  0.768182
# accuracy    0.729230  0.729230
# f1-measure  0.777812  0.653456
# | Validation Accuracy : 72.92 % - Macro F1 Score : 0.7156
# | CM on the Validation :
# [[1255.  513.]
#  [ 204.  676.]]
#
# =============================================================================
#
# 14 {'model': 'RNN', 'score': 0.7156339926097812, 'task': 'subtask_a', 'hidden_size': -50, 'num_layer': 2, 'lr': 0.001, 'weight_decay': 0.001, 'middle_layers': [200]}
# | Epoch: 00 | Train Loss: 0.524 | Train Acc: 76.30%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.867354  0.575859
# recall      0.713801  0.780682
# accuracy    0.736027  0.736027
# f1-measure  0.783121  0.662808
# | Validation Accuracy : 73.60 % - Macro F1 Score : 0.7230
# | CM on the Validation :
# [[1262.  506.]
#  [ 193.  687.]]
#
# =============================================================================
#
# 15 {'model': 'RNN', 'score': 0.7229644204350694, 'task': 'subtask_a', 'hidden_size': -50, 'num_layer': 2, 'lr': 0.001, 'weight_decay': 0.01, 'middle_layers': [200]}
# | Epoch: 00 | Train Loss: 0.436 | Train Acc: 64.35%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.836664  0.537176
# recall      0.686652  0.730682
# accuracy    0.701284  0.701284
# f1-measure  0.754272  0.619162
# | Validation Accuracy : 70.13 % - Macro F1 Score : 0.6867
# | CM on the Validation :
# [[1214.  554.]
#  [ 237.  643.]]
#
# =============================================================================
#
# 16 {'model': 'RNN', 'score': 0.6867168830710411, 'task': 'subtask_a', 'hidden_size': -50, 'num_layer': 2, 'lr': 0.01, 'weight_decay': 0, 'middle_layers': [200]}
# | Epoch: 00 | Train Loss: 0.545 | Train Acc: 63.43%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.831047  0.511481
# recall      0.651018  0.734091
# accuracy    0.678625  0.678625
# f1-measure  0.730098  0.602893
# | Validation Accuracy : 67.86 % - Macro F1 Score : 0.6665
# | CM on the Validation :
# [[1151.  617.]
#  [ 234.  646.]]
#
# =============================================================================
#
# 17 {'model': 'RNN', 'score': 0.6664957297592572, 'task': 'subtask_a', 'hidden_size': -50, 'num_layer': 2, 'lr': 0.01, 'weight_decay': 0.001, 'middle_layers': [200]}
# | Epoch: 00 | Train Loss: 0.632 | Train Acc: 59.98%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.707306  0.521834
# recall      0.876131  0.271591
# accuracy    0.675227  0.675227
# f1-measure  0.782719  0.357250
# | Validation Accuracy : 67.52 % - Macro F1 Score : 0.5700
# | CM on the Validation :
# [[1549.  219.]
#  [ 641.  239.]]
#
# =============================================================================
#
# 18 {'model': 'RNN', 'score': 0.5699840855137388, 'task': 'subtask_a', 'hidden_size': -50, 'num_layer': 2, 'lr': 0.01, 'weight_decay': 0.01, 'middle_layers': [200]}
# | Epoch: 00 | Train Loss: 0.690 | Train Acc: 61.88%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.770068  0.460102
# recall      0.640271  0.615909
# accuracy    0.632175  0.632175
# f1-measure  0.699197  0.526725
# | Validation Accuracy : 63.22 % - Macro F1 Score : 0.6130
# | CM on the Validation :
# [[1132.  636.]
#  [ 338.  542.]]
#
# =============================================================================
#
# 19 {'model': 'RNN', 'score': 0.6129610054557427, 'task': 'subtask_a', 'hidden_size': -50, 'num_layer': 2, 'lr': 0.0001, 'weight_decay': 0, 'middle_layers': [200, 100]}
# | Epoch: 00 | Train Loss: 0.638 | Train Acc: 65.80%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.781095  0.507692
# recall      0.710407  0.600000
# accuracy    0.673716  0.673716
# f1-measure  0.744076  0.550000
# | Validation Accuracy : 67.37 % - Macro F1 Score : 0.6470
# | CM on the Validation :
# [[1256.  512.]
#  [ 352.  528.]]
#
# =============================================================================
#
# 20 {'model': 'RNN', 'score': 0.6470379146919432, 'task': 'subtask_a', 'hidden_size': -50, 'num_layer': 2, 'lr': 0.0001, 'weight_decay': 0.001, 'middle_layers': [200, 100]}
# | Epoch: 00 | Train Loss: 0.557 | Train Acc: 69.09%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.790160  0.547347
# recall      0.753959  0.597727
# accuracy    0.702039  0.702039
# f1-measure  0.771635  0.571429
# | Validation Accuracy : 70.20 % - Macro F1 Score : 0.6715
# | CM on the Validation :
# [[1333.  435.]
#  [ 354.  526.]]
#
# =============================================================================
#
# 21 {'model': 'RNN', 'score': 0.6715319412859211, 'task': 'subtask_a', 'hidden_size': -50, 'num_layer': 2, 'lr': 0.0001, 'weight_decay': 0.01, 'middle_layers': [200, 100]}
# | Epoch: 00 | Train Loss: 0.492 | Train Acc: 72.72%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.865807  0.528969
# recall      0.645928  0.798864
# accuracy    0.696752  0.696752
# f1-measure  0.739877  0.636487
# | Validation Accuracy : 69.68 % - Macro F1 Score : 0.6882
# | CM on the Validation :
# [[1142.  626.]
#  [ 177.  703.]]
#
# =============================================================================
#
# 22 {'model': 'RNN', 'score': 0.6881820006883522, 'task': 'subtask_a', 'hidden_size': -50, 'num_layer': 2, 'lr': 0.001, 'weight_decay': 0, 'middle_layers': [200, 100]}
# | Epoch: 00 | Train Loss: 0.448 | Train Acc: 75.58%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.873660  0.532787
# recall      0.645362  0.812500
# accuracy    0.700906  0.700906
# f1-measure  0.742355  0.643564
# | Validation Accuracy : 70.09 % - Macro F1 Score : 0.6930
# | CM on the Validation :
# [[1141.  627.]
#  [ 165.  715.]]
#
# =============================================================================
#
# 23 {'model': 'RNN', 'score': 0.6929597969556227, 'task': 'subtask_a', 'hidden_size': -50, 'num_layer': 2, 'lr': 0.001, 'weight_decay': 0.001, 'middle_layers': [200, 100]}
# | Epoch: 00 | Train Loss: 0.550 | Train Acc: 75.99%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.848426  0.590284
# recall      0.747172  0.731818
# accuracy    0.742069  0.742069
# f1-measure  0.794586  0.653475
# | Validation Accuracy : 74.21 % - Macro F1 Score : 0.7240
# | CM on the Validation :
# [[1321.  447.]
#  [ 236.  644.]]
#
# =============================================================================
#
# 24 {'model': 'RNN', 'score': 0.7240309296834171, 'task': 'subtask_a', 'hidden_size': -50, 'num_layer': 2, 'lr': 0.001, 'weight_decay': 0.01, 'middle_layers': [200, 100]}
# | Epoch: 00 | Train Loss: 0.609 | Train Acc: 60.12%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.775199  0.474561
# recall      0.661199  0.614773
# accuracy    0.645770  0.645770
# f1-measure  0.713675  0.535644
# | Validation Accuracy : 64.58 % - Macro F1 Score : 0.6247
# | CM on the Validation :
# [[1169.  599.]
#  [ 339.  541.]]
#
# =============================================================================
#
# 25 {'model': 'RNN', 'score': 0.6246593890158247, 'task': 'subtask_a', 'hidden_size': -50, 'num_layer': 2, 'lr': 0.01, 'weight_decay': 0, 'middle_layers': [200, 100]}
# | Epoch: 00 | Train Loss: 0.672 | Train Acc: 58.65%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.765517  0.427401
# recall      0.565045  0.652273
# accuracy    0.594033  0.594033
# f1-measure  0.650179  0.516419
# | Validation Accuracy : 59.40 % - Macro F1 Score : 0.5833
# | CM on the Validation :
# [[999. 769.]
#  [306. 574.]]
#
# =============================================================================
#
# 26 {'model': 'RNN', 'score': 0.58329911572928, 'task': 'subtask_a', 'hidden_size': -50, 'num_layer': 2, 'lr': 0.01, 'weight_decay': 0.001, 'middle_layers': [200, 100]}
# | Epoch: 00 | Train Loss: 0.532 | Train Acc: 60.37%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.901141  0.390198
# recall      0.268100  0.940909
# accuracy    0.491692  0.491692
# f1-measure  0.413252  0.551632
# | Validation Accuracy : 49.17 % - Macro F1 Score : 0.4824
# | CM on the Validation :
# [[ 474. 1294.]
#  [  52.  828.]]
#
# =============================================================================
#
# 27 {'model': 'RNN', 'score': 0.4824421034044726, 'task': 'subtask_a', 'hidden_size': -50, 'num_layer': 2, 'lr': 0.01, 'weight_decay': 0.01, 'middle_layers': [200, 100]}
# | Epoch: 00 | Train Loss: 0.447 | Train Acc: 68.84%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.766832  0.651274
# recall      0.876131  0.464773
# accuracy    0.739426  0.739426
# f1-measure  0.817846  0.542440
# | Validation Accuracy : 73.94 % - Macro F1 Score : 0.6801
# | CM on the Validation :
# [[1549.  219.]
#  [ 471.  409.]]
#
# =============================================================================
#
# 28 {'model': 'RNN', 'score': 0.6801430736179307, 'task': 'subtask_a', 'hidden_size': 0, 'num_layer': 2, 'lr': 0.0001, 'weight_decay': 0, 'middle_layers': []}
# | Epoch: 00 | Train Loss: 0.518 | Train Acc: 68.51%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.774974  0.605898
# recall      0.833710  0.513636
# accuracy    0.727341  0.727341
# f1-measure  0.803270  0.555966
# | Validation Accuracy : 72.73 % - Macro F1 Score : 0.6796
# | CM on the Validation :
# [[1474.  294.]
#  [ 428.  452.]]
#
# =============================================================================
#
# 29 {'model': 'RNN', 'score': 0.6796176572119945, 'task': 'subtask_a', 'hidden_size': 0, 'num_layer': 2, 'lr': 0.0001, 'weight_decay': 0.001, 'middle_layers': []}
# | Epoch: 00 | Train Loss: 0.718 | Train Acc: 70.03%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.796023  0.586712
# recall      0.792421  0.592045
# accuracy    0.725831  0.725831
# f1-measure  0.794218  0.589367
# | Validation Accuracy : 72.58 % - Macro F1 Score : 0.6918
# | CM on the Validation :
# [[1401.  367.]
#  [ 359.  521.]]
#
# =============================================================================
#
# 30 {'model': 'RNN', 'score': 0.691792101455967, 'task': 'subtask_a', 'hidden_size': 0, 'num_layer': 2, 'lr': 0.0001, 'weight_decay': 0.01, 'middle_layers': []}
# | Epoch: 00 | Train Loss: 0.476 | Train Acc: 71.24%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.847856  0.549085
# recall      0.693439  0.750000
# accuracy    0.712236  0.712236
# f1-measure  0.762912  0.634006
# | Validation Accuracy : 71.22 % - Macro F1 Score : 0.6985
# | CM on the Validation :
# [[1226.  542.]
#  [ 220.  660.]]
#
# =============================================================================
#
# 31 {'model': 'RNN', 'score': 0.6984590112781078, 'task': 'subtask_a', 'hidden_size': 0, 'num_layer': 2, 'lr': 0.001, 'weight_decay': 0, 'middle_layers': []}
# | Epoch: 00 | Train Loss: 0.459 | Train Acc: 75.02%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.833726  0.628151
# recall      0.799774  0.679545
# accuracy    0.759819  0.759819
# f1-measure  0.816397  0.652838
# | Validation Accuracy : 75.98 % - Macro F1 Score : 0.7346
# | CM on the Validation :
# [[1414.  354.]
#  [ 282.  598.]]
#
# =============================================================================
#
# 32 {'model': 'RNN', 'score': 0.7346178282925058, 'task': 'subtask_a', 'hidden_size': 0, 'num_layer': 2, 'lr': 0.001, 'weight_decay': 0.001, 'middle_layers': []}
# | Epoch: 00 | Train Loss: 0.544 | Train Acc: 76.46%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.864714  0.565074
# recall      0.701357  0.779545
# accuracy    0.727341  0.727341
# f1-measure  0.774516  0.655205
# | Validation Accuracy : 72.73 % - Macro F1 Score : 0.7149
# | CM on the Validation :
# [[1240.  528.]
#  [ 194.  686.]]
#
# =============================================================================
#
# 33 {'model': 'RNN', 'score': 0.7148606380801874, 'task': 'subtask_a', 'hidden_size': 0, 'num_layer': 2, 'lr': 0.001, 'weight_decay': 0.01, 'middle_layers': []}
# | Epoch: 00 | Train Loss: 0.564 | Train Acc: 59.76%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.786466  0.452200
# recall      0.591629  0.677273
# accuracy    0.620091  0.620091
# f1-measure  0.675274  0.542311
# | Validation Accuracy : 62.01 % - Macro F1 Score : 0.6088
# | CM on the Validation :
# [[1046.  722.]
#  [ 284.  596.]]
#
# =============================================================================
#
# 34 {'model': 'RNN', 'score': 0.6087927812771867, 'task': 'subtask_a', 'hidden_size': 0, 'num_layer': 2, 'lr': 0.01, 'weight_decay': 0, 'middle_layers': []}
# | Epoch: 00 | Train Loss: 0.627 | Train Acc: 62.82%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.779971  0.452344
# recall      0.603507  0.657955
# accuracy    0.621601  0.621601
# f1-measure  0.680485  0.536111
# | Validation Accuracy : 62.16 % - Macro F1 Score : 0.6083
# | CM on the Validation :
# [[1067.  701.]
#  [ 301.  579.]]
#
# =============================================================================
#
# 35 {'model': 'RNN', 'score': 0.6082979024943311, 'task': 'subtask_a', 'hidden_size': 0, 'num_layer': 2, 'lr': 0.01, 'weight_decay': 0.001, 'middle_layers': []}
# | Epoch: 00 | Train Loss: 0.632 | Train Acc: 58.54%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.819222  0.480927
# recall      0.607466  0.730682
# accuracy    0.648414  0.648414
# f1-measure  0.697629  0.580063
# | Validation Accuracy : 64.84 % - Macro F1 Score : 0.6388
# | CM on the Validation :
# [[1074.  694.]
#  [ 237.  643.]]
#
# =============================================================================
#
# 36 {'model': 'RNN', 'score': 0.6388461243779979, 'task': 'subtask_a', 'hidden_size': 0, 'num_layer': 2, 'lr': 0.01, 'weight_decay': 0.01, 'middle_layers': []}
# | Epoch: 00 | Train Loss: 0.547 | Train Acc: 68.17%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.810038  0.540968
# recall      0.721154  0.660227
# accuracy    0.700906  0.700906
# f1-measure  0.763016  0.594678
# | Validation Accuracy : 70.09 % - Macro F1 Score : 0.6788
# | CM on the Validation :
# [[1275.  493.]
#  [ 299.  581.]]
#
# =============================================================================
#
# 37 {'model': 'RNN', 'score': 0.678846871215699, 'task': 'subtask_a', 'hidden_size': 0, 'num_layer': 2, 'lr': 0.0001, 'weight_decay': 0, 'middle_layers': [200]}
# | Epoch: 00 | Train Loss: 0.761 | Train Acc: 69.71%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.792368  0.588915
# recall      0.798643  0.579545
# accuracy    0.725831  0.725831
# f1-measure  0.795493  0.584192
# | Validation Accuracy : 72.58 % - Macro F1 Score : 0.6898
# | CM on the Validation :
# [[1412.  356.]
#  [ 370.  510.]]
#
# =============================================================================
#
# 38 {'model': 'RNN', 'score': 0.689842698804511, 'task': 'subtask_a', 'hidden_size': 0, 'num_layer': 2, 'lr': 0.0001, 'weight_decay': 0.001, 'middle_layers': [200]}
# | Epoch: 00 | Train Loss: 0.450 | Train Acc: 70.81%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.806627  0.565789
# recall      0.757353  0.635227
# accuracy    0.716767  0.716767
# f1-measure  0.781214  0.598501
# | Validation Accuracy : 71.68 % - Macro F1 Score : 0.6899
# | CM on the Validation :
# [[1339.  429.]
#  [ 321.  559.]]
#
# =============================================================================
#
# 39 {'model': 'RNN', 'score': 0.6898573031265383, 'task': 'subtask_a', 'hidden_size': 0, 'num_layer': 2, 'lr': 0.0001, 'weight_decay': 0.01, 'middle_layers': [200]}
# | Epoch: 00 | Train Loss: 0.435 | Train Acc: 72.28%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.808982  0.611924
# recall      0.804864  0.618182
# accuracy    0.742825  0.742825
# f1-measure  0.806918  0.615037
# | Validation Accuracy : 74.28 % - Macro F1 Score : 0.7110
# | CM on the Validation :
# [[1423.  345.]
#  [ 336.  544.]]
#
# =============================================================================
#
# 40 {'model': 'RNN', 'score': 0.7109774022989575, 'task': 'subtask_a', 'hidden_size': 0, 'num_layer': 2, 'lr': 0.001, 'weight_decay': 0, 'middle_layers': [200]}
# | Epoch: 00 | Train Loss: 0.530 | Train Acc: 75.82%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.830769  0.591398
# recall      0.763575  0.687500
# accuracy    0.738293  0.738293
# f1-measure  0.795756  0.635838
# | Validation Accuracy : 73.83 % - Macro F1 Score : 0.7158
# | CM on the Validation :
# [[1350.  418.]
#  [ 275.  605.]]
#
# =============================================================================
#
# 41 {'model': 'RNN', 'score': 0.7157970592293893, 'task': 'subtask_a', 'hidden_size': 0, 'num_layer': 2, 'lr': 0.001, 'weight_decay': 0.001, 'middle_layers': [200]}
# | Epoch: 00 | Train Loss: 0.613 | Train Acc: 75.84%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.811810  0.644737
# recall      0.832014  0.612500
# accuracy    0.759063  0.759063
# f1-measure  0.821788  0.628205
# | Validation Accuracy : 75.91 % - Macro F1 Score : 0.7250
# | CM on the Validation :
# [[1471.  297.]
#  [ 341.  539.]]
#
# =============================================================================
#
# 42 {'model': 'RNN', 'score': 0.7249964188511675, 'task': 'subtask_a', 'hidden_size': 0, 'num_layer': 2, 'lr': 0.001, 'weight_decay': 0.01, 'middle_layers': [200]}
# | Epoch: 00 | Train Loss: 0.629 | Train Acc: 62.55%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.788945  0.515152
# recall      0.710407  0.618182
# accuracy    0.679758  0.679758
# f1-measure  0.747619  0.561983
# | Validation Accuracy : 67.98 % - Macro F1 Score : 0.6548
# | CM on the Validation :
# [[1256.  512.]
#  [ 336.  544.]]
#
# =============================================================================
#
# 43 {'model': 'RNN', 'score': 0.6548012593467138, 'task': 'subtask_a', 'hidden_size': 0, 'num_layer': 2, 'lr': 0.01, 'weight_decay': 0, 'middle_layers': [200]}
# | Epoch: 00 | Train Loss: 0.637 | Train Acc: 66.64%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.776645  0.643377
# recall      0.861425  0.502273
# accuracy    0.742069  0.742069
# f1-measure  0.816841  0.564135
# | Validation Accuracy : 74.21 % - Macro F1 Score : 0.6905
# | CM on the Validation :
# [[1523.  245.]
#  [ 438.  442.]]
#
# =============================================================================
#
# 44 {'model': 'RNN', 'score': 0.690488133248382, 'task': 'subtask_a', 'hidden_size': 0, 'num_layer': 2, 'lr': 0.01, 'weight_decay': 0.001, 'middle_layers': [200]}
# | Epoch: 00 | Train Loss: 0.655 | Train Acc: 60.66%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.750764  0.466864
# recall      0.695136  0.536364
# accuracy    0.642372  0.642372
# f1-measure  0.721880  0.499207
# | Validation Accuracy : 64.24 % - Macro F1 Score : 0.6105
# | CM on the Validation :
# [[1229.  539.]
#  [ 408.  472.]]
#
# =============================================================================
#
# 45 {'model': 'RNN', 'score': 0.6105431788726412, 'task': 'subtask_a', 'hidden_size': 0, 'num_layer': 2, 'lr': 0.01, 'weight_decay': 0.01, 'middle_layers': [200]}
# | Epoch: 00 | Train Loss: 0.612 | Train Acc: 61.59%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.753005  0.476626
# recall      0.708710  0.532955
# accuracy    0.650302  0.650302
# f1-measure  0.730186  0.503219
# | Validation Accuracy : 65.03 % - Macro F1 Score : 0.6167
# | CM on the Validation :
# [[1253.  515.]
#  [ 411.  469.]]
#
# =============================================================================
#
# 46 {'model': 'RNN', 'score': 0.6167026821533259, 'task': 'subtask_a', 'hidden_size': 0, 'num_layer': 2, 'lr': 0.0001, 'weight_decay': 0, 'middle_layers': [200, 100]}
# | Epoch: 00 | Train Loss: 0.609 | Train Acc: 62.27%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.761108  0.464840
# recall      0.668552  0.578409
# accuracy    0.638595  0.638595
# f1-measure  0.711834  0.515443
# | Validation Accuracy : 63.86 % - Macro F1 Score : 0.6136
# | CM on the Validation :
# [[1182.  586.]
#  [ 371.  509.]]
#
# =============================================================================
#
# 47 {'model': 'RNN', 'score': 0.6136384114896001, 'task': 'subtask_a', 'hidden_size': 0, 'num_layer': 2, 'lr': 0.0001, 'weight_decay': 0.001, 'middle_layers': [200, 100]}
# | Epoch: 00 | Train Loss: 0.567 | Train Acc: 63.27%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.769132  0.476670
# recall      0.676471  0.592045
# accuracy    0.648414  0.648414
# f1-measure  0.719831  0.528130
# | Validation Accuracy : 64.84 % - Macro F1 Score : 0.6240
# | CM on the Validation :
# [[1196.  572.]
#  [ 359.  521.]]
#
# =============================================================================
#
# 48 {'model': 'RNN', 'score': 0.6239806146138687, 'task': 'subtask_a', 'hidden_size': 0, 'num_layer': 2, 'lr': 0.0001, 'weight_decay': 0.01, 'middle_layers': [200, 100]}
# | Epoch: 00 | Train Loss: 0.476 | Train Acc: 70.43%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.859387  0.527841
# recall      0.649887  0.786364
# accuracy    0.695242  0.695242
# f1-measure  0.740097  0.631675
# | Validation Accuracy : 69.52 % - Macro F1 Score : 0.6859
# | CM on the Validation :
# [[1149.  619.]
#  [ 188.  692.]]
#
# =============================================================================
#
# 49 {'model': 'RNN', 'score': 0.6858858262942163, 'task': 'subtask_a', 'hidden_size': 0, 'num_layer': 2, 'lr': 0.001, 'weight_decay': 0, 'middle_layers': [200, 100]}
# | Epoch: 00 | Train Loss: 0.468 | Train Acc: 74.73%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.831283  0.629118
# recall      0.802602  0.672727
# accuracy    0.759441  0.759441
# f1-measure  0.816691  0.650192
# | Validation Accuracy : 75.94 % - Macro F1 Score : 0.7334
# | CM on the Validation :
# [[1419.  349.]
#  [ 288.  592.]]
#
# =============================================================================
#
# 50 {'model': 'RNN', 'score': 0.7334414247843899, 'task': 'subtask_a', 'hidden_size': 0, 'num_layer': 2, 'lr': 0.001, 'weight_decay': 0.001, 'middle_layers': [200, 100]}
# | Epoch: 00 | Train Loss: 0.426 | Train Acc: 75.70%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.885805  0.530642
# recall      0.631787  0.836364
# accuracy    0.699773  0.699773
# f1-measure  0.737537  0.649316
# | Validation Accuracy : 69.98 % - Macro F1 Score : 0.6934
# | CM on the Validation :
# [[1117.  651.]
#  [ 144.  736.]]
#
# =============================================================================
#
# 51 {'model': 'RNN', 'score': 0.6934267089943515, 'task': 'subtask_a', 'hidden_size': 0, 'num_layer': 2, 'lr': 0.001, 'weight_decay': 0.01, 'middle_layers': [200, 100]}
# | Epoch: 00 | Train Loss: 0.746 | Train Acc: 61.60%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.792740  0.391862
# recall      0.382919  0.798864
# accuracy    0.521148  0.521148
# f1-measure  0.516400  0.525804
# | Validation Accuracy : 52.11 % - Macro F1 Score : 0.5211
# | CM on the Validation :
# [[ 677. 1091.]
#  [ 177.  703.]]
#
# =============================================================================
#
# 52 {'model': 'RNN', 'score': 0.5211018668912208, 'task': 'subtask_a', 'hidden_size': 0, 'num_layer': 2, 'lr': 0.01, 'weight_decay': 0, 'middle_layers': [200, 100]}
# | Epoch: 00 | Train Loss: 0.524 | Train Acc: 68.16%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.746485  0.724605
# recall      0.930995  0.364773
# accuracy    0.742825  0.742825
# f1-measure  0.828593  0.485261
# | Validation Accuracy : 74.28 % - Macro F1 Score : 0.6569
# | CM on the Validation :
# [[1646.  122.]
#  [ 559.  321.]]
#
# =============================================================================
#
# 53 {'model': 'RNN', 'score': 0.6569268868718727, 'task': 'subtask_a', 'hidden_size': 0, 'num_layer': 2, 'lr': 0.01, 'weight_decay': 0.001, 'middle_layers': [200, 100]}
# | Epoch: 00 | Train Loss: 0.606 | Train Acc: 62.81%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.789938  0.423762
# recall      0.506222  0.729545
# accuracy    0.580438  0.580438
# f1-measure  0.617029  0.536117
# | Validation Accuracy : 58.04 % - Macro F1 Score : 0.5766
# | CM on the Validation :
# [[895. 873.]
#  [238. 642.]]
#
# =============================================================================
#
# 54 {'model': 'RNN', 'score': 0.5765727605267494, 'task': 'subtask_a', 'hidden_size': 0, 'num_layer': 2, 'lr': 0.01, 'weight_decay': 0.01, 'middle_layers': [200, 100]}
# | Epoch: 00 | Train Loss: 0.557 | Train Acc: 66.00%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.767483  0.516094
# recall      0.744910  0.546591
# accuracy    0.679003  0.679003
# f1-measure  0.756028  0.530905
# | Validation Accuracy : 67.90 % - Macro F1 Score : 0.6435
# | CM on the Validation :
# [[1317.  451.]
#  [ 399.  481.]]
#
# =============================================================================
#
# 55 {'model': 'RNN', 'score': 0.6434663158988552, 'task': 'subtask_a', 'hidden_size': 50, 'num_layer': 2, 'lr': 0.0001, 'weight_decay': 0, 'middle_layers': []}
# | Epoch: 00 | Train Loss: 0.552 | Train Acc: 68.22%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.794740  0.514233
# recall      0.700792  0.636364
# accuracy    0.679381  0.679381
# f1-measure  0.744815  0.568817
# | Validation Accuracy : 67.94 % - Macro F1 Score : 0.6568
# | CM on the Validation :
# [[1239.  529.]
#  [ 320.  560.]]
#
# =============================================================================
#
# 56 {'model': 'RNN', 'score': 0.65681590349241, 'task': 'subtask_a', 'hidden_size': 50, 'num_layer': 2, 'lr': 0.0001, 'weight_decay': 0.001, 'middle_layers': []}
# | Epoch: 00 | Train Loss: 0.568 | Train Acc: 70.20%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.798378  0.577007
# recall      0.779412  0.604545
# accuracy    0.721299  0.721299
# f1-measure  0.788781  0.590455
# | Validation Accuracy : 72.13 % - Macro F1 Score : 0.6896
# | CM on the Validation :
# [[1378.  390.]
#  [ 348.  532.]]
#
# =============================================================================
#
# 57 {'model': 'RNN', 'score': 0.6896179084868495, 'task': 'subtask_a', 'hidden_size': 50, 'num_layer': 2, 'lr': 0.0001, 'weight_decay': 0.01, 'middle_layers': []}
# | Epoch: 00 | Train Loss: 0.579 | Train Acc: 72.26%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.840847  0.546453
# recall      0.696267  0.735227
# accuracy    0.709215  0.709215
# f1-measure  0.761757  0.626938
# | Validation Accuracy : 70.92 % - Macro F1 Score : 0.6943
# | CM on the Validation :
# [[1231.  537.]
#  [ 233.  647.]]
#
# =============================================================================
#
# 58 {'model': 'RNN', 'score': 0.6943477051193492, 'task': 'subtask_a', 'hidden_size': 50, 'num_layer': 2, 'lr': 0.001, 'weight_decay': 0, 'middle_layers': []}
# | Epoch: 00 | Train Loss: 0.789 | Train Acc: 74.92%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.791469  0.646195
# recall      0.850113  0.550000
# accuracy    0.750378  0.750378
# f1-measure  0.819744  0.594230
# | Validation Accuracy : 75.04 % - Macro F1 Score : 0.7070
# | CM on the Validation :
# [[1503.  265.]
#  [ 396.  484.]]
#
# =============================================================================
#
# 59 {'model': 'RNN', 'score': 0.706986624186015, 'task': 'subtask_a', 'hidden_size': 50, 'num_layer': 2, 'lr': 0.001, 'weight_decay': 0.001, 'middle_layers': []}
# | Epoch: 00 | Train Loss: 0.639 | Train Acc: 75.40%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.837855  0.601365
# recall      0.768665  0.701136
# accuracy    0.746224  0.746224
# f1-measure  0.801770  0.647429
# | Validation Accuracy : 74.62 % - Macro F1 Score : 0.7246
# | CM on the Validation :
# [[1359.  409.]
#  [ 263.  617.]]
#
# =============================================================================
#
# 60 {'model': 'RNN', 'score': 0.7245995412716248, 'task': 'subtask_a', 'hidden_size': 50, 'num_layer': 2, 'lr': 0.001, 'weight_decay': 0.01, 'middle_layers': []}
# | Epoch: 00 | Train Loss: 0.660 | Train Acc: 56.76%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.730978  0.411565
# recall      0.608597  0.550000
# accuracy    0.589124  0.589124
# f1-measure  0.664198  0.470817
# | Validation Accuracy : 58.91 % - Macro F1 Score : 0.5675
# | CM on the Validation :
# [[1076.  692.]
#  [ 396.  484.]]
#
# =============================================================================
#
# 61 {'model': 'RNN', 'score': 0.5675073257433828, 'task': 'subtask_a', 'hidden_size': 50, 'num_layer': 2, 'lr': 0.01, 'weight_decay': 0, 'middle_layers': []}
# | Epoch: 00 | Train Loss: 0.594 | Train Acc: 59.60%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.755889  0.543590
# recall      0.798643  0.481818
# accuracy    0.693353  0.693353
# f1-measure  0.776678  0.510843
# | Validation Accuracy : 69.34 % - Macro F1 Score : 0.6438
# | CM on the Validation :
# [[1412.  356.]
#  [ 456.  424.]]
#
# =============================================================================
#
# 62 {'model': 'RNN', 'score': 0.6437605206303763, 'task': 'subtask_a', 'hidden_size': 50, 'num_layer': 2, 'lr': 0.01, 'weight_decay': 0.001, 'middle_layers': []}
# | Epoch: 00 | Train Loss: 0.697 | Train Acc: 60.15%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.755365  0.351054
# recall      0.199095  0.870455
# accuracy    0.422205  0.422205
# f1-measure  0.315130  0.500327
# | Validation Accuracy : 42.22 % - Macro F1 Score : 0.4077
# | CM on the Validation :
# [[ 352. 1416.]
#  [ 114.  766.]]
#
# =============================================================================
#
# 63 {'model': 'RNN', 'score': 0.40772819796424475, 'task': 'subtask_a', 'hidden_size': 50, 'num_layer': 2, 'lr': 0.01, 'weight_decay': 0.01, 'middle_layers': []}
# | Epoch: 00 | Train Loss: 0.697 | Train Acc: 58.16%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.733374  0.439049
# recall      0.679864  0.503409
# accuracy    0.621224  0.621224
# f1-measure  0.705606  0.469031
# | Validation Accuracy : 62.12 % - Macro F1 Score : 0.5873
# | CM on the Validation :
# [[1202.  566.]
#  [ 437.  443.]]
#
# =============================================================================
#
# 64 {'model': 'RNN', 'score': 0.5873186692673182, 'task': 'subtask_a', 'hidden_size': 50, 'num_layer': 2, 'lr': 0.0001, 'weight_decay': 0, 'middle_layers': [200]}
# | Epoch: 00 | Train Loss: 0.660 | Train Acc: 60.47%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.742142  0.469892
# recall      0.721154  0.496591
# accuracy    0.646526  0.646526
# f1-measure  0.731497  0.482873
# | Validation Accuracy : 64.65 % - Macro F1 Score : 0.6072
# | CM on the Validation :
# [[1275.  493.]
#  [ 443.  437.]]
#
# =============================================================================
#
# 65 {'model': 'RNN', 'score': 0.6071851732106008, 'task': 'subtask_a', 'hidden_size': 50, 'num_layer': 2, 'lr': 0.0001, 'weight_decay': 0.001, 'middle_layers': [200]}
# | Epoch: 00 | Train Loss: 0.659 | Train Acc: 61.55%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.755685  0.494105
# recall      0.733032  0.523864
# accuracy    0.663520  0.663520
# f1-measure  0.744186  0.508549
# | Validation Accuracy : 66.35 % - Macro F1 Score : 0.6264
# | CM on the Validation :
# [[1296.  472.]
#  [ 419.  461.]]
#
# =============================================================================
#
# 66 {'model': 'RNN', 'score': 0.6263677061019254, 'task': 'subtask_a', 'hidden_size': 50, 'num_layer': 2, 'lr': 0.0001, 'weight_decay': 0.01, 'middle_layers': [200]}
# | Epoch: 00 | Train Loss: 0.716 | Train Acc: 68.31%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.726051  0.727273
# recall      0.947398  0.281818
# accuracy    0.726208  0.726208
# f1-measure  0.822086  0.406224
# | Validation Accuracy : 72.62 % - Macro F1 Score : 0.6142
# | CM on the Validation :
# [[1675.   93.]
#  [ 632.  248.]]
#
# =============================================================================
#
# 67 {'model': 'RNN', 'score': 0.6141551478974792, 'task': 'subtask_a', 'hidden_size': 50, 'num_layer': 2, 'lr': 0.001, 'weight_decay': 0, 'middle_layers': [200]}
# | Epoch: 00 | Train Loss: 0.649 | Train Acc: 72.08%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.825107  0.588878
# recall      0.765837  0.673864
# accuracy    0.735272  0.735272
# f1-measure  0.794368  0.628511
# | Validation Accuracy : 73.53 % - Macro F1 Score : 0.7114
# | CM on the Validation :
# [[1354.  414.]
#  [ 287.  593.]]
#
# =============================================================================
#
# 68 {'model': 'RNN', 'score': 0.7114393568071549, 'task': 'subtask_a', 'hidden_size': 50, 'num_layer': 2, 'lr': 0.001, 'weight_decay': 0.001, 'middle_layers': [200]}
# | Epoch: 00 | Train Loss: 0.476 | Train Acc: 73.14%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.823944  0.614407
# recall      0.794118  0.659091
# accuracy    0.749245  0.749245
# f1-measure  0.808756  0.635965
# | Validation Accuracy : 74.92 % - Macro F1 Score : 0.7224
# | CM on the Validation :
# [[1404.  364.]
#  [ 300.  580.]]
#
# =============================================================================
#
# 69 {'model': 'RNN', 'score': 0.7223603363246827, 'task': 'subtask_a', 'hidden_size': 50, 'num_layer': 2, 'lr': 0.001, 'weight_decay': 0.01, 'middle_layers': [200]}
# | Epoch: 00 | Train Loss: 0.658 | Train Acc: 61.92%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.773623  0.464741
# recall      0.643665  0.621591
# accuracy    0.636329  0.636329
# f1-measure  0.702686  0.531842
# | Validation Accuracy : 63.63 % - Macro F1 Score : 0.6173
# | CM on the Validation :
# [[1138.  630.]
#  [ 333.  547.]]
#
# =============================================================================
#
# 70 {'model': 'RNN', 'score': 0.6172642516318272, 'task': 'subtask_a', 'hidden_size': 50, 'num_layer': 2, 'lr': 0.01, 'weight_decay': 0, 'middle_layers': [200]}
# | Epoch: 00 | Train Loss: 0.609 | Train Acc: 66.23%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.898667  0.370436
# recall      0.190611  0.956818
# accuracy    0.445242  0.445242
# f1-measure  0.314512  0.534095
# | Validation Accuracy : 44.52 % - Macro F1 Score : 0.4243
# | CM on the Validation :
# [[ 337. 1431.]
#  [  38.  842.]]
#
# =============================================================================
#
# 71 {'model': 'RNN', 'score': 0.42430343950217253, 'task': 'subtask_a', 'hidden_size': 50, 'num_layer': 2, 'lr': 0.01, 'weight_decay': 0.001, 'middle_layers': [200]}
# | Epoch: 00 | Train Loss: 0.590 | Train Acc: 64.46%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.800911  0.516652
# recall      0.696267  0.652273
# accuracy    0.681647  0.681647
# f1-measure  0.744932  0.576595
# | Validation Accuracy : 68.16 % - Macro F1 Score : 0.6608
# | CM on the Validation :
# [[1231.  537.]
#  [ 306.  574.]]
#
# =============================================================================
#
# 72 {'model': 'RNN', 'score': 0.660763298686753, 'task': 'subtask_a', 'hidden_size': 50, 'num_layer': 2, 'lr': 0.01, 'weight_decay': 0.01, 'middle_layers': [200]}
# | Epoch: 00 | Train Loss: 0.578 | Train Acc: 70.39%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.794622  0.578889
# recall      0.785633  0.592045
# accuracy    0.721299  0.721299
# f1-measure  0.790102  0.585393
# | Validation Accuracy : 72.13 % - Macro F1 Score : 0.6877
# | CM on the Validation :
# [[1389.  379.]
#  [ 359.  521.]]
#
# =============================================================================
#
# 73 {'model': 'RNN', 'score': 0.6877478237527324, 'task': 'subtask_a', 'hidden_size': 50, 'num_layer': 2, 'lr': 0.0001, 'weight_decay': 0, 'middle_layers': [200, 100]}
# | Epoch: 00 | Train Loss: 0.733 | Train Acc: 70.88%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.807468  0.588865
# recall      0.782805  0.625000
# accuracy    0.730363  0.730363
# f1-measure  0.794945  0.606395
# | Validation Accuracy : 73.04 % - Macro F1 Score : 0.7007
# | CM on the Validation :
# [[1384.  384.]
#  [ 330.  550.]]
#
# =============================================================================
#
# 74 {'model': 'RNN', 'score': 0.7006700707434106, 'task': 'subtask_a', 'hidden_size': 50, 'num_layer': 2, 'lr': 0.0001, 'weight_decay': 0.001, 'middle_layers': [200, 100]}
# | Epoch: 00 | Train Loss: 0.445 | Train Acc: 72.41%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.821514  0.592480
# recall      0.773190  0.662500
# accuracy    0.736405  0.736405
# f1-measure  0.796620  0.625536
# | Validation Accuracy : 73.64 % - Macro F1 Score : 0.7111
# | CM on the Validation :
# [[1367.  401.]
#  [ 297.  583.]]
#
# =============================================================================
#
# 75 {'model': 'RNN', 'score': 0.711078263653371, 'task': 'subtask_a', 'hidden_size': 50, 'num_layer': 2, 'lr': 0.0001, 'weight_decay': 0.01, 'middle_layers': [200, 100]}
# | Epoch: 00 | Train Loss: 0.574 | Train Acc: 73.94%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.822821  0.631637
# recall      0.811652  0.648864
# accuracy    0.757553  0.757553
# f1-measure  0.817198  0.640135
# | Validation Accuracy : 75.76 % - Macro F1 Score : 0.7287
# | CM on the Validation :
# [[1435.  333.]
#  [ 309.  571.]]
#
# =============================================================================
#
# 76 {'model': 'RNN', 'score': 0.7286663534122598, 'task': 'subtask_a', 'hidden_size': 50, 'num_layer': 2, 'lr': 0.001, 'weight_decay': 0, 'middle_layers': [200, 100]}
# | Epoch: 00 | Train Loss: 0.485 | Train Acc: 76.69%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.861241  0.584856
# recall      0.730204  0.763636
# accuracy    0.741314  0.741314
# f1-measure  0.790328  0.662395
# | Validation Accuracy : 74.13 % - Macro F1 Score : 0.7264
# | CM on the Validation :
# [[1291.  477.]
#  [ 208.  672.]]
#
# =============================================================================
#
# 77 {'model': 'RNN', 'score': 0.7263613931027346, 'task': 'subtask_a', 'hidden_size': 50, 'num_layer': 2, 'lr': 0.001, 'weight_decay': 0.001, 'middle_layers': [200, 100]}
# | Epoch: 00 | Train Loss: 0.535 | Train Acc: 76.99%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.840826  0.616766
# recall      0.782805  0.702273
# accuracy    0.756042  0.756042
# f1-measure  0.810779  0.656748
# | Validation Accuracy : 75.60 % - Macro F1 Score : 0.7338
# | CM on the Validation :
# [[1384.  384.]
#  [ 262.  618.]]
#
# =============================================================================
#
# 78 {'model': 'RNN', 'score': 0.7337636424873015, 'task': 'subtask_a', 'hidden_size': 50, 'num_layer': 2, 'lr': 0.001, 'weight_decay': 0.01, 'middle_layers': [200, 100]}
# | Epoch: 00 | Train Loss: 0.575 | Train Acc: 60.77%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.786463  0.410256
# recall      0.466629  0.745455
# accuracy    0.559290  0.559290
# f1-measure  0.585729  0.529246
# | Validation Accuracy : 55.93 % - Macro F1 Score : 0.5575
# | CM on the Validation :
# [[825. 943.]
#  [224. 656.]]
#
# =============================================================================
#
# 79 {'model': 'RNN', 'score': 0.5574875815207703, 'task': 'subtask_a', 'hidden_size': 50, 'num_layer': 2, 'lr': 0.01, 'weight_decay': 0, 'middle_layers': [200, 100]}
# | Epoch: 00 | Train Loss: 0.776 | Train Acc: 61.52%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.777508  0.428470
# recall      0.543552  0.687500
# accuracy    0.591390  0.591390
# f1-measure  0.639814  0.527923
# | Validation Accuracy : 59.14 % - Macro F1 Score : 0.5839
# | CM on the Validation :
# [[961. 807.]
#  [275. 605.]]
#
# =============================================================================
#
# 80 {'model': 'RNN', 'score': 0.5838683965300484, 'task': 'subtask_a', 'hidden_size': 50, 'num_layer': 2, 'lr': 0.01, 'weight_decay': 0.001, 'middle_layers': [200, 100]}
# | Epoch: 00 | Train Loss: 0.690 | Train Acc: 62.74%
# | Stats on the Validation :
#                  NOT       OFF
# precision   0.725282  0.408414
# recall      0.618213  0.529545
# accuracy    0.588746  0.588746
# f1-measure  0.667481  0.461158
# | Validation Accuracy : 58.87 % - Macro F1 Score : 0.5643
# | CM on the Validation :
# [[1093.  675.]
#  [ 414.  466.]]
#
# ...
# | Stats on the Validation :
#                  UNT       TIN
# precision   0.194690  0.892950
# recall      0.211538  0.882581
# accuracy    0.803185  0.803185
# f1-measure  0.202765  0.887735
# | Validation Accuracy : 80.32 % - Macro F1 Score : 0.5453
# | CM on the Validation :
# [[ 22.  82.]
#  [ 91. 684.]]
#
# =============================================================================
#
# 462 {'model': 'GRU', 'score': 0.5452501069088538, 'task': 'subtask_b', 'hidden_size': 50, 'num_layer': 2, 'lr': 0.0001, 'weight_decay': 0.01, 'middle_layers': []}
# | Epoch: 00 | Train Loss: 0.012 | Train Acc: 98.05%
# | Stats on the Validation :
#                  UNT       TIN
# precision   0.180723  0.888191
# recall      0.144231  0.912258
# accuracy    0.821388  0.821388
# f1-measure  0.160428  0.900064
# | Validation Accuracy : 82.14 % - Macro F1 Score : 0.5302
# | CM on the Validation :
# [[ 15.  89.]
#  [ 68. 707.]]
#
# =============================================================================
#
# 463 {'model': 'GRU', 'score': 0.530245730605187, 'task': 'subtask_b', 'hidden_size': 50, 'num_layer': 2, 'lr': 0.001, 'weight_decay': 0, 'middle_layers': []}
# | Epoch: 00 | Train Loss: 0.003 | Train Acc: 99.06%
# | Stats on the Validation :
#                  UNT       TIN
# precision   0.191919  0.891026
# recall      0.182692  0.896774
# accuracy    0.812287  0.812287
# f1-measure  0.187192  0.893891
# | Validation Accuracy : 81.23 % - Macro F1 Score : 0.5405
# | CM on the Validation :
# [[ 19.  85.]
#  [ 80. 695.]]
#
# =============================================================================
#
# 464 {'model': 'GRU', 'score': 0.5405413967338792, 'task': 'subtask_b', 'hidden_size': 50, 'num_layer': 2, 'lr': 0.001, 'weight_decay': 0.001, 'middle_layers': []}
# | Epoch: 00 | Train Loss: 0.096 | Train Acc: 99.05%
# | Stats on the Validation :
#                  UNT       TIN
# precision   0.174757  0.889175
# recall      0.173077  0.890323
# accuracy    0.805461  0.805461
# f1-measure  0.173913  0.889749
# | Validation Accuracy : 80.55 % - Macro F1 Score : 0.5318
# | CM on the Validation :
# [[ 18.  86.]
#  [ 85. 690.]]
#
# =============================================================================
#
# 465 {'model': 'GRU', 'score': 0.5318307964006391, 'task': 'subtask_b', 'hidden_size': 50, 'num_layer': 2, 'lr': 0.001, 'weight_decay': 0.01, 'middle_layers': []}
# | Epoch: 00 | Train Loss: 0.056 | Train Acc: 93.49%
# | Stats on the Validation :
#                  UNT       TIN
# precision   0.156250  0.884663
# recall      0.096154  0.930323
# accuracy    0.831627  0.831627
# f1-measure  0.119048  0.906918
# | Validation Accuracy : 83.16 % - Macro F1 Score : 0.5130
# | CM on the Validation :
# [[ 10.  94.]
#  [ 54. 721.]]
#
# =============================================================================
#
# 466 {'model': 'GRU', 'score': 0.5129829290206649, 'task': 'subtask_b', 'hidden_size': 50, 'num_layer': 2, 'lr': 0.01, 'weight_decay': 0, 'middle_layers': []}
# | Epoch: 00 | Train Loss: 0.000 | Train Acc: 96.05%
# | Stats on the Validation :
#                  UNT       TIN
# precision   0.164062  0.889481
# recall      0.201923  0.861935
# accuracy    0.783845  0.783845
# f1-measure  0.181034  0.875491
# | Validation Accuracy : 78.38 % - Macro F1 Score : 0.5283
# | CM on the Validation :
# [[ 21.  83.]
#  [107. 668.]]
#
# =============================================================================
#
# 467 {'model': 'GRU', 'score': 0.5282629818773444, 'task': 'subtask_b', 'hidden_size': 50, 'num_layer': 2, 'lr': 0.01, 'weight_decay': 0.001, 'middle_layers': []}
# | Epoch: 00 | Train Loss: 0.086 | Train Acc: 95.27%
# | Stats on the Validation :
#                  UNT       TIN
# precision   0.214689  0.905983
# recall      0.365385  0.820645
# accuracy    0.766780  0.766780
# f1-measure  0.270463  0.861205
# | Validation Accuracy : 76.68 % - Macro F1 Score : 0.5658
# | CM on the Validation :
# [[ 38.  66.]
#  [139. 636.]]
#
# =============================================================================
#
# 468 {'model': 'GRU', 'score': 0.5658338895086462, 'task': 'subtask_b', 'hidden_size': 50, 'num_layer': 2, 'lr': 0.01, 'weight_decay': 0.01, 'middle_layers': []}
# | Epoch: 00 | Train Loss: 0.033 | Train Acc: 96.43%
# | Stats on the Validation :
#                  UNT       TIN
# precision   0.195312  0.894807
# recall      0.240385  0.867097
# accuracy    0.792947  0.792947
# f1-measure  0.215517  0.880734
# | Validation Accuracy : 79.29 % - Macro F1 Score : 0.5481
# | CM on the Validation :
# [[ 25.  79.]
#  [103. 672.]]
#
# =============================================================================
#
# 469 {'model': 'GRU', 'score': 0.5481255931667194, 'task': 'subtask_b', 'hidden_size': 50, 'num_layer': 2, 'lr': 0.0001, 'weight_decay': 0, 'middle_layers': [200]}
# | Epoch: 00 | Train Loss: 0.042 | Train Acc: 97.41%
# | Stats on the Validation :
#                  UNT       TIN
# precision   0.192308  0.894526
# recall      0.240385  0.864516
# accuracy    0.790671  0.790671
# f1-measure  0.213675  0.879265
# | Validation Accuracy : 79.07 % - Macro F1 Score : 0.5465
# | CM on the Validation :
# [[ 25.  79.]
#  [105. 670.]]
#
# =============================================================================
#
# 470 {'model': 'GRU', 'score': 0.5464701527693654, 'task': 'subtask_b', 'hidden_size': 50, 'num_layer': 2, 'lr': 0.0001, 'weight_decay': 0.001, 'middle_layers': [200]}
# | Epoch: 00 | Train Loss: 0.032 | Train Acc: 98.02%
# | Stats on the Validation :
#                  UNT       TIN
# precision   0.187500  0.893475
# recall      0.230769  0.865806
# accuracy    0.790671  0.790671
# f1-measure  0.206897  0.879423
# | Validation Accuracy : 79.07 % - Macro F1 Score : 0.5432
# | CM on the Validation :
# [[ 24.  80.]
#  [104. 671.]]
#
# =============================================================================
#
# 471 {'model': 'GRU', 'score': 0.5431599403443756, 'task': 'subtask_b', 'hidden_size': 50, 'num_layer': 2, 'lr': 0.0001, 'weight_decay': 0.01, 'middle_layers': [200]}
# | Epoch: 00 | Train Loss: 0.019 | Train Acc: 98.48%
# | Stats on the Validation :
#                  UNT       TIN
# precision   0.192771  0.889447
# recall      0.153846  0.913548
# accuracy    0.823663  0.823663
# f1-measure  0.171123  0.901337
# | Validation Accuracy : 82.37 % - Macro F1 Score : 0.5362
# | CM on the Validation :
# [[ 16.  88.]
#  [ 67. 708.]]
#
# =============================================================================
#
# 472 {'model': 'GRU', 'score': 0.536229861425503, 'task': 'subtask_b', 'hidden_size': 50, 'num_layer': 2, 'lr': 0.001, 'weight_decay': 0, 'middle_layers': [200]}
# | Epoch: 00 | Train Loss: 0.025 | Train Acc: 99.05%
# | Stats on the Validation :
#                  UNT       TIN
# precision   0.196262  0.892487
# recall      0.201923  0.889032
# accuracy    0.807736  0.807736
# f1-measure  0.199052  0.890756
# | Validation Accuracy : 80.77 % - Macro F1 Score : 0.5449
# | CM on the Validation :
# [[ 21.  83.]
#  [ 86. 689.]]
#
# =============================================================================
#
# 473 {'model': 'GRU', 'score': 0.5449042176112151, 'task': 'subtask_b', 'hidden_size': 50, 'num_layer': 2, 'lr': 0.001, 'weight_decay': 0.001, 'middle_layers': [200]}
# | Epoch: 00 | Train Loss: 0.013 | Train Acc: 99.10%
# | Stats on the Validation :
#                  UNT       TIN
# precision   0.182540  0.892430
# recall      0.221154  0.867097
# accuracy    0.790671  0.790671
# f1-measure  0.200000  0.879581
# | Validation Accuracy : 79.07 % - Macro F1 Score : 0.5398
# | CM on the Validation :
# [[ 23.  81.]
#  [103. 672.]]
#
# =============================================================================
#
# 474 {'model': 'GRU', 'score': 0.5397905759162304, 'task': 'subtask_b', 'hidden_size': 50, 'num_layer': 2, 'lr': 0.001, 'weight_decay': 0.01, 'middle_layers': [200]}
# | Epoch: 00 | Train Loss: 0.054 | Train Acc: 93.22%
# | Stats on the Validation :
#                  UNT       TIN
# precision   0.196581  0.893701
# recall      0.221154  0.878710
# accuracy    0.800910  0.800910
# f1-measure  0.208145  0.886142
# | Validation Accuracy : 80.09 % - Macro F1 Score : 0.5471
# | CM on the Validation :
# [[ 23.  81.]
#  [ 94. 681.]]
#
# =============================================================================
#
# 475 {'model': 'GRU', 'score': 0.5471433155615482, 'task': 'subtask_b', 'hidden_size': 50, 'num_layer': 2, 'lr': 0.01, 'weight_decay': 0, 'middle_layers': [200]}
# | Epoch: 00 | Train Loss: 0.064 | Train Acc: 96.22%
# | Stats on the Validation :
#                  UNT       TIN
# precision   0.203125  0.888344
# recall      0.125000  0.934194
# accuracy    0.838453  0.838453
# f1-measure  0.154762  0.910692
# | Validation Accuracy : 83.85 % - Macro F1 Score : 0.5327
# | CM on the Validation :
# [[ 13.  91.]
#  [ 51. 724.]]
#
# =============================================================================
#
# 476 {'model': 'GRU', 'score': 0.532726864330638, 'task': 'subtask_b', 'hidden_size': 50, 'num_layer': 2, 'lr': 0.01, 'weight_decay': 0.001, 'middle_layers': [200]}
# | Epoch: 00 | Train Loss: 0.223 | Train Acc: 95.03%
# | Stats on the Validation :
#                  UNT       TIN
# precision   0.208333  0.889715
# recall      0.144231  0.926452
# accuracy    0.833902  0.833902
# f1-measure  0.170455  0.907712
# | Validation Accuracy : 83.39 % - Macro F1 Score : 0.5391
# | CM on the Validation :
# [[ 15.  89.]
#  [ 57. 718.]]
#
# =============================================================================
#
# 477 {'model': 'GRU', 'score': 0.5390831513619124, 'task': 'subtask_b', 'hidden_size': 50, 'num_layer': 2, 'lr': 0.01, 'weight_decay': 0.01, 'middle_layers': [200]}
# | Epoch: 00 | Train Loss: 1.700 | Train Acc: 95.44%
# | Stats on the Validation :
#                  UNT       TIN
# precision   0.210938  0.897470
# recall      0.259615  0.869677
# accuracy    0.797497  0.797497
# f1-measure  0.232759  0.883355
# | Validation Accuracy : 79.75 % - Macro F1 Score : 0.5581
# | CM on the Validation :
# [[ 27.  77.]
#  [101. 674.]]
#
# =============================================================================
#
# 478 {'model': 'GRU', 'score': 0.5580568988114069, 'task': 'subtask_b', 'hidden_size': 50, 'num_layer': 2, 'lr': 0.0001, 'weight_decay': 0, 'middle_layers': [200, 100]}
# | Epoch: 00 | Train Loss: 0.006 | Train Acc: 97.25%
# | Stats on the Validation :
#                  UNT       TIN
# precision   0.195312  0.894807
# recall      0.240385  0.867097
# accuracy    0.792947  0.792947
# f1-measure  0.215517  0.880734
# | Validation Accuracy : 79.29 % - Macro F1 Score : 0.5481
# | CM on the Validation :
# [[ 25.  79.]
#  [103. 672.]]
#
# =============================================================================
#
# 479 {'model': 'GRU', 'score': 0.5481255931667194, 'task': 'subtask_b', 'hidden_size': 50, 'num_layer': 2, 'lr': 0.0001, 'weight_decay': 0.001, 'middle_layers': [200, 100]}
# | Epoch: 00 | Train Loss: 0.083 | Train Acc: 97.65%
# | Stats on the Validation :
#                  UNT       TIN
# precision   0.179487  0.891076
# recall      0.201923  0.876129
# accuracy    0.796359  0.796359
# f1-measure  0.190045  0.883539
# | Validation Accuracy : 79.64 % - Macro F1 Score : 0.5368
# | CM on the Validation :
# [[ 21.  83.]
#  [ 96. 679.]]
#
# =============================================================================
#
# 480 {'model': 'GRU', 'score': 0.5367923056315265, 'task': 'subtask_b', 'hidden_size': 50, 'num_layer': 2, 'lr': 0.0001, 'weight_decay': 0.01, 'middle_layers': [200, 100]}
# | Epoch: 00 | Train Loss: 0.040 | Train Acc: 98.25%
# | Stats on the Validation :
#                  UNT       TIN
# precision   0.182540  0.892430
# recall      0.221154  0.867097
# accuracy    0.790671  0.790671
# f1-measure  0.200000  0.879581
# | Validation Accuracy : 79.07 % - Macro F1 Score : 0.5398
# | CM on the Validation :
# [[ 23.  81.]
#  [103. 672.]]
#
# =============================================================================
#
# 481 {'model': 'GRU', 'score': 0.5397905759162304, 'task': 'subtask_b', 'hidden_size': 50, 'num_layer': 2, 'lr': 0.001, 'weight_decay': 0, 'middle_layers': [200, 100]}
# | Epoch: 00 | Train Loss: 0.002 | Train Acc: 98.90%
# | Stats on the Validation :
#                  UNT       TIN
# precision   0.184466  0.890464
# recall      0.182692  0.891613
# accuracy    0.807736  0.807736
# f1-measure  0.183575  0.891038
# | Validation Accuracy : 80.77 % - Macro F1 Score : 0.5373
# | CM on the Validation :
# [[ 19.  85.]
#  [ 84. 691.]]
#
# =============================================================================
#
# 482 {'model': 'GRU', 'score': 0.5373064596006316, 'task': 'subtask_b', 'hidden_size': 50, 'num_layer': 2, 'lr': 0.001, 'weight_decay': 0.001, 'middle_layers': [200, 100]}
# | Epoch: 00 | Train Loss: 0.013 | Train Acc: 99.06%
# | Stats on the Validation :
#                  UNT       TIN
# precision   0.210526  0.892857
# recall      0.192308  0.903226
# accuracy    0.819113  0.819113
# f1-measure  0.201005  0.898012
# | Validation Accuracy : 81.91 % - Macro F1 Score : 0.5495
# | CM on the Validation :
# [[ 20.  84.]
#  [ 75. 700.]]
#
# =============================================================================
#
# 483 {'model': 'GRU', 'score': 0.5495082854941804, 'task': 'subtask_b', 'hidden_size': 50, 'num_layer': 2, 'lr': 0.001, 'weight_decay': 0.01, 'middle_layers': [200, 100]}
# | Epoch: 00 | Train Loss: 0.010 | Train Acc: 93.89%
# | Stats on the Validation :
#                  UNT       TIN
# precision   0.189873  0.888750
# recall      0.144231  0.917419
# accuracy    0.825939  0.825939
# f1-measure  0.163934  0.902857
# | Validation Accuracy : 82.59 % - Macro F1 Score : 0.5334
# | CM on the Validation :
# [[ 15.  89.]
#  [ 64. 711.]]
#
# =============================================================================
#
# 484 {'model': 'GRU', 'score': 0.5333957845433255, 'task': 'subtask_b', 'hidden_size': 50, 'num_layer': 2, 'lr': 0.01, 'weight_decay': 0, 'middle_layers': [200, 100]}
# | Epoch: 00 | Train Loss: 0.050 | Train Acc: 95.87%
# | Stats on the Validation :
#                  UNT       TIN
# precision   0.200000  0.892765
# recall      0.201923  0.891613
# accuracy    0.810011  0.810011
# f1-measure  0.200957  0.892189
# | Validation Accuracy : 81.00 % - Macro F1 Score : 0.5466
# | CM on the Validation :
# [[ 21.  83.]
#  [ 84. 691.]]
#
# =============================================================================
#
# 485 {'model': 'GRU', 'score': 0.5465727232571717, 'task': 'subtask_b', 'hidden_size': 50, 'num_layer': 2, 'lr': 0.01, 'weight_decay': 0.001, 'middle_layers': [200, 100]}
# | Epoch: 00 | Train Loss: 1.154 | Train Acc: 94.16%
# | Stats on the Validation :
#                  UNT       TIN
# precision   0.208955  0.889163
# recall      0.134615  0.931613
# accuracy    0.837315  0.837315
# f1-measure  0.163743  0.909893
# | Validation Accuracy : 83.73 % - Macro F1 Score : 0.5368
# | CM on the Validation :
# [[ 14.  90.]
#  [ 53. 722.]]
#
# =============================================================================
#
# 486 {'model': 'GRU', 'score': 0.5368177848528062, 'task': 'subtask_b', 'hidden_size': 50, 'num_layer': 2, 'lr': 0.01, 'weight_decay': 0.01, 'middle_layers': [200, 100]}
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-144-9a7df217aa98> in <module>
#      58                                optimizer= optimizer ,
#      59                                model= model ,
# ---> 60                                batch_size= 100)
#      61
#      62                         if isinstance(model,RNN):
#
# <ipython-input-128-037a67f2a042> in train(self, nb_epochs, optimizer, model, batch_size)
#      62                 predictions = torch.argmax(output,dim=1).float()
#      63                 loss = loss_fn(output, target)
# ---> 64                 acc, correct = self.accuracy(predictions, target)
#      65                 accuracy_average += acc
#      66                 #calculate the gradient of each parameter
#
# <ipython-input-128-037a67f2a042> in accuracy(self, output, target)
#     153
#     154     def accuracy(self, output, target):
# --> 155         target = np.array(target.tolist()).astype(int)
#     156         output = np.array(torch.round(output).tolist()).astype(int)
#     157         correct = (output == target)
#
# RuntimeError: CUDA error: device-side assert triggered

# %%
import pandas as pd

res_df = pd.DataFrame(results)
res_df.loc[res_df.task == "subtask_b"].loc[res_df.model == "GRU"].sort_values(by=["score"],ascending=[False]).iloc[:15]
# Out:
#      hidden_size      lr middle_layers model  num_layer     score       task  \
# 427          -50  0.0010    [200, 100]   GRU          2  0.574421  subtask_b
# 467           50  0.0100            []   GRU          2  0.565834  subtask_b
# 457            0  0.0100    [200, 100]   GRU          2  0.558140  subtask_b
# 477           50  0.0001    [200, 100]   GRU          2  0.558057  subtask_b
# 417          -50  0.0010         [200]   GRU          2  0.557426  subtask_b
# 419          -50  0.0010         [200]   GRU          2  0.557362  subtask_b
# 426          -50  0.0010    [200, 100]   GRU          2  0.554605  subtask_b
# 411          -50  0.0100            []   GRU          2  0.552327  subtask_b
# 437            0  0.0010            []   GRU          2  0.552075  subtask_b
# 441            0  0.0001         [200]   GRU          2  0.550560  subtask_b
# 482           50  0.0010    [200, 100]   GRU          2  0.549508  subtask_b
# 431          -50  0.0100    [200, 100]   GRU          2  0.549057  subtask_b
# 424          -50  0.0001    [200, 100]   GRU          2  0.548629  subtask_b
# 425          -50  0.0001    [200, 100]   GRU          2  0.548190  subtask_b
# 478           50  0.0001    [200, 100]   GRU          2  0.548126  subtask_b
#
#      weight_decay
# 427         0.001
# 467         0.010
# 457         0.001
# 477         0.000
# 417         0.000
# 419         0.010
# 426         0.000
# 411         0.000
# 437         0.010
# 441         0.000
# 482         0.010
# 431         0.010
# 424         0.001
# 425         0.010
# 478         0.001
